# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.0 MB 3.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.0 MB 1.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 346 kB 974 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 502 kB 1.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pf=pd.read_csv('Titanic_Passengers.csv')

# %%
pf
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
p1=pf[['pclass','survived','name']][0:4:]

# %%
p2=pf[['pclass','age','fare']][4:8:]
p2
# Out:
#    pclass   age      fare
# 4       1  25.0  151.5500
# 5       1  48.0   26.5500
# 6       1  63.0   77.9583
# 7       1  39.0    0.0000

# %%
p3=p1.merge(p2,'outer',)
p3
# Out:
#     pclass  survived                                  name   age      fare
# 0        1         1         Allen, Miss. Elisabeth Walton  25.0  151.5500
# 1        1         1         Allen, Miss. Elisabeth Walton  48.0   26.5500
# 2        1         1         Allen, Miss. Elisabeth Walton  63.0   77.9583
# 3        1         1         Allen, Miss. Elisabeth Walton  39.0    0.0000
# 4        1         1        Allison, Master. Hudson Trevor  25.0  151.5500
# 5        1         1        Allison, Master. Hudson Trevor  48.0   26.5500
# 6        1         1        Allison, Master. Hudson Trevor  63.0   77.9583
# 7        1         1        Allison, Master. Hudson Trevor  39.0    0.0000
# 8        1         0          Allison, Miss. Helen Loraine  25.0  151.5500
# 9        1         0          Allison, Miss. Helen Loraine  48.0   26.5500
# 10       1         0          Allison, Miss. Helen Loraine  63.0   77.9583
# ...

# %%
pf.fillna('somi')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket     fare    cabin embarked  boat  \
# ...

# %%
p4=pf.groupby('survived')
