# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages (4.3.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages (from gensim) (7.0.4)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: wrapt in /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
#        -5.46875000e-02,  1.53198242e-02, -1.62109375e-01,  1.58203125e-01,
#        -2.59765625e-01,  2.01416016e-02, -1.63085938e-01,  1.35803223e-03,
#        -1.44531250e-01, -5.68847656e-02,  4.29687500e-02, -2.46582031e-02,
#         1.85546875e-01,  4.47265625e-01,  9.58251953e-03,  1.31835938e-01,
#         9.86328125e-02, -1.85546875e-01, -1.00097656e-01, -1.33789062e-01,
#        -1.25000000e-01,  2.83203125e-01,  1.23046875e-01,  5.32226562e-02,
#        -1.77734375e-01,  8.59375000e-02, -2.18505859e-02,  2.05078125e-02,
#        -1.39648438e-01,  2.51464844e-02,  1.38671875e-01, -1.05468750e-01,
#         1.38671875e-01,  8.88671875e-02, -7.51953125e-02, -2.13623047e-02,
#         1.72851562e-01,  4.63867188e-02, -2.65625000e-01,  8.91113281e-03,
#         1.49414062e-01,  3.78417969e-02,  2.38281250e-01, -1.24511719e-01,
#        -2.17773438e-01, -1.81640625e-01,  2.97851562e-02,  5.71289062e-02,
#        -2.89306641e-02,  1.24511719e-02,  9.66796875e-02, -2.31445312e-01,
#         5.81054688e-02,  6.68945312e-02,  7.08007812e-02, -3.08593750e-01,
#        -2.14843750e-01,  1.45507812e-01, -4.27734375e-01, -9.39941406e-03,
#         1.54296875e-01, -7.66601562e-02,  2.89062500e-01,  2.77343750e-01,
#        -4.86373901e-04, -1.36718750e-01,  3.24218750e-01, -2.46093750e-01,
#        -3.03649902e-03, -2.11914062e-01,  1.25000000e-01,  2.69531250e-01,
#         2.04101562e-01,  8.25195312e-02, -2.01171875e-01, -1.60156250e-01,
#        -3.78417969e-02, -1.20117188e-01,  1.15234375e-01, -4.10156250e-02,
#        -3.95507812e-02, -8.98437500e-02,  6.34765625e-03,  2.03125000e-01,
#         1.86523438e-01,  2.73437500e-01,  6.29882812e-02,  1.41601562e-01,
#        -9.81445312e-02,  1.38671875e-01,  1.82617188e-01,  1.73828125e-01,
#         1.73828125e-01, -2.37304688e-01,  1.78710938e-01,  6.34765625e-02,
#         2.36328125e-01, -2.08984375e-01,  8.74023438e-02, -1.66015625e-01,
#        -7.91015625e-02,  2.43164062e-01, -8.88671875e-02,  1.26953125e-01,
#        -2.16796875e-01, -1.73828125e-01, -3.59375000e-01, -8.25195312e-02,
#        -6.49414062e-02,  5.07812500e-02,  1.35742188e-01, -7.47070312e-02,
#        -1.64062500e-01,  1.15356445e-02,  4.45312500e-01, -2.15820312e-01,
#        -1.11328125e-01, -1.92382812e-01,  1.70898438e-01, -1.25000000e-01,
#         2.65502930e-03,  1.92382812e-01, -1.74804688e-01,  1.39648438e-01,
#         2.92968750e-01,  1.13281250e-01,  5.95703125e-02, -6.39648438e-02,
#         9.96093750e-02, -2.72216797e-02,  1.96533203e-02,  4.27246094e-02,
#        -2.46093750e-01,  6.39648438e-02, -2.25585938e-01, -1.68945312e-01,
#         2.89916992e-03,  8.20312500e-02,  3.41796875e-01,  4.32128906e-02,
#         1.32812500e-01,  1.42578125e-01,  7.61718750e-02,  5.98144531e-02,
#        -1.19140625e-01,  2.74658203e-03, -6.29882812e-02, -2.72216797e-02,
#        -4.82177734e-03, -8.20312500e-02, -2.49023438e-02, -4.00390625e-01,
#        -1.06933594e-01,  4.24804688e-02,  7.76367188e-02, -1.16699219e-01,
#         7.37304688e-02, -9.22851562e-02,  1.07910156e-01,  1.58203125e-01,
#         4.24804688e-02,  1.26953125e-01,  3.61328125e-02,  2.67578125e-01,
#        -1.01074219e-01, -3.02734375e-01, -5.76171875e-02,  5.05371094e-02,
#         5.26428223e-04, -2.07031250e-01, -1.38671875e-01, -8.97216797e-03,
#        -2.78320312e-02, -1.41601562e-01,  2.07031250e-01, -1.58203125e-01,
#         1.27929688e-01,  1.49414062e-01, -2.24609375e-02, -8.44726562e-02,
#         1.22558594e-01,  2.15820312e-01, -2.13867188e-01, -3.12500000e-01,
#        -3.73046875e-01,  4.08935547e-03,  1.07421875e-01,  1.06933594e-01,
#         7.32421875e-02,  8.97216797e-03, -3.88183594e-02, -1.29882812e-01,
#         1.49414062e-01, -2.14843750e-01, -1.83868408e-03,  9.91210938e-02,
#         1.57226562e-01, -1.14257812e-01, -2.05078125e-01,  9.91210938e-02,
#         3.69140625e-01, -1.97265625e-01,  3.54003906e-02,  1.09375000e-01,
#         1.31835938e-01,  1.66992188e-01,  2.35351562e-01,  1.04980469e-01,
#        -4.96093750e-01, -1.64062500e-01, -1.56250000e-01, -5.22460938e-02,
#         1.03027344e-01,  2.43164062e-01, -1.88476562e-01,  5.07812500e-02,
#        -9.37500000e-02, -6.68945312e-02,  2.27050781e-02,  7.61718750e-02,
#         2.89062500e-01,  3.10546875e-01, -5.37109375e-02,  2.28515625e-01,
#         2.51464844e-02,  6.78710938e-02, -1.21093750e-01, -2.15820312e-01,
#        -2.73437500e-01, -3.07617188e-02, -3.37890625e-01,  1.53320312e-01,
#         2.33398438e-01, -2.08007812e-01,  3.73046875e-01,  8.20312500e-02,
#         2.51953125e-01, -7.61718750e-02, -4.66308594e-02, -2.23388672e-02,
#         2.99072266e-02, -5.93261719e-02, -4.66918945e-03, -2.44140625e-01,
#        -2.09960938e-01, -2.87109375e-01, -4.54101562e-02, -1.77734375e-01,
#        -2.79296875e-01, -8.59375000e-02,  9.13085938e-02,  2.51953125e-01],
#       dtype=float32)

# %%
import pandas as pd
messages=pd.read_csv('SMSSpamCollection.txt',
                    sep='\t',names=["label","message"])

# %%
messages.shape
# Out:
# (5572, 2)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/cybesama/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(word) for word in review]
    review = ' '.join(review)
    corpus.append(review)

# %%
[[i,j,k] for i,j,k in zip(list(map(len,corpus)),corpus, messages['message']) if i<1]
# Out:
# [[0, '', '645'], [0, '', ':) '], [0, '', ':-) :-)']]

# %%
corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
#  'had your mobile month or more u r entitled to update to the latest colour mobile with camera for free call the mobile update co free on',
#  'i m gonna be home soon and i don t want to talk about this stuff anymore tonight k i ve cried enough today',
#  'six chance to win cash from to pound txt csh and send to cost p day day tsandcs apply reply hl info',
#  'urgent you have won a week free membership in our prize jackpot txt the word claim to no t c www dbuk net lccltd pobox ldnw a rw',
#  'i ve been searching for the right word to thank you for this breather i promise i wont take your help for granted and will fulfil my promise you have been wonderful and a blessing at all time',
#  'i have a date on sunday with will',
#  'xxxmobilemovieclub to use your credit click the wap link in the next txt message or click here http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'oh k i m watching here',
#  'eh u remember how spell his name yes i did he v naughty make until i v wet',
#  'fine if that s the way u feel that s the way it gota b',
#  'england v macedonia dont miss the goal team news txt ur national team to eg england to try wale scotland txt poboxox w wq',
#  'is that seriously how you spell his name',
#  'i m going to try for month ha ha only joking',
#  'so pay first lar then when is da stock comin',
#  'aft i finish my lunch then i go str down lor ard smth lor u finish ur lunch already',
#  'ffffffffff alright no way i can meet up with you sooner',
#  'just forced myself to eat a slice i m really not hungry tho this suck mark is getting worried he know i m sick when i turn down pizza lol',
#  'lol your always so convincing',
#  'did you catch the bus are you frying an egg did you make a tea are you eating your mom s left over dinner do you feel my love',
#  'i m back amp we re packing the car now i ll let you know if there s room',
#  'ahhh work i vaguely remember that what doe it feel like lol',
#  'wait that s still not all that clear were you not sure about me being sarcastic or that that s why x doesn t want to live with u',
#  'yeah he got in at and wa v apologetic n had fallen out and she wa actin like spoilt child and he got caught up in that till but we won t go there not doing too badly cheer you',
#  'k tell me anything about you',
#  'for fear of fainting with the of all that housework you just did quick have a cuppa',
#  'thanks for your subscription to ringtone uk your mobile will be charged month please confirm by replying yes or no if you reply no you will not be charged',
#  'yup ok i go home look at the timing then i msg again xuhui going to learn on nd may too but her lesson is at am',
#  'oops i ll let you know when my roommate s done',
#  'i see the letter b on my car',
#  'anything lor u decide',
#  'hello how s you and how did saturday go i wa just texting to see if you d decided to do anything tomo not that i m trying to invite myself or anything',
#  'pls go ahead with watt i just wanted to be sure do have a great weekend abiola',
#  'did i forget to tell you i want you i need you i crave you but most of all i love you my sweet arabian steed mmmmmm yummy',
#  'rodger burn msg we tried to call you re your reply to our sm for a free nokia mobile free camcorder please call now for delivery tomorrow',
#  'who are you seeing',
#  'great i hope you like your man well endowed i am lt gt inch',
#  'no call message missed call',
#  'didn t you get hep b immunisation in nigeria',
#  'fair enough anything going on',
#  'yeah hopefully if tyler can t do it i could maybe ask around a bit',
#  'u don t know how stubborn i am i didn t even want to go to the hospital i kept telling mark i m not a weak sucker hospital are for weak sucker',
#  'what you thinked about me first time you saw me in class',
#  'a gram usually run like lt gt a half eighth is smarter though and get you almost a whole second gram for lt gt',
#  'k fyi x ha a ride early tomorrow morning but he s crashing at our place tonight',
#  'wow i never realized that you were so embarassed by your accomodations i thought you liked it since i wa doing the best i could and you always seemed so happy about the cave i m sorry i didn t and don t have more to give i m sorry i offered i m sorry your room wa so embarassing',
#  'sm ac sptv the new jersey devil and the detroit red wing play ice hockey correct or incorrect end reply end sptv',
#  'do you know what mallika sherawat did yesterday find out now lt url gt',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry i ll call later in meeting',
#  'tell where you reached',
#  'yes gauti and sehwag out of odi series',
#  'your gonna have to pick up a burger for yourself on your way home i can t even move pain is killing me',
#  'ha ha ha good joke girl are situation seeker',
#  'it a part of checking iq',
#  'sorry my roommate took forever it ok if i come by now',
#  'ok lar i double check wif da hair dresser already he said wun cut v short he said will cut until i look nice',
#  'a a valued customer i am pleased to advise you that following recent review of your mob no you are awarded with a bonus prize call',
#  'today is song dedicated day which song will u dedicate for me send this to all ur valuable frnds but first rply me',
#  'urgent ur awarded a complimentary trip to eurodisinc trav aco entry or to claim txt dis to morefrmmob shracomorsglsuplt l aj',
#  'did you hear about the new divorce barbie it come with all of ken s stuff',
#  'i plane to give on this month end',
#  'wah lucky man then can save money hee',
#  'finished class where are you',
#  'hi babe im at home now wanna do something xx',
#  'k k where are you how did you performed',
#  'u can call me now',
#  'i am waiting machan call me once you free',
#  'thats cool i am a gentleman and will treat you with dignity and respect',
#  'i like you people very much but am very shy pa',
#  'doe not operate after lt gt or what',
#  'it not the same here still looking for a job how much do ta s earn there',
#  'sorry i ll call later',
#  'k did you call me just now ah',
#  'ok i am on the way to home hi hi',
#  'you will be in the place of that man',
#  'yup next stop',
#  'i call you later don t have network if urgnt sm me',
#  'for real when u getting on yo i only need more ticket and one more jacket and i m done i already used all my multis',
#  'yes i started to send request to make it but pain came back so i m back in bed double coin at the factory too i gotta cash in all my nitros',
#  'i m really not up to it still tonight babe',
#  'ela kano il download come wen ur free',
#  'yeah do don t stand to close tho you ll catch something',
#  'sorry to be a pain is it ok if we meet another night i spent late afternoon in casualty and that mean i haven t done any of y stuff moro and that includes all my time sheet and that sorry',
#  'smile in pleasure smile in pain smile when trouble pours like rain smile when sum hurt u smile becoz someone still love to see u smiling',
#  'please call our customer service representative on between am pm a you have won a guaranteed cash or prize',
#  'havent planning to buy later i check already lido only got show in e afternoon u finish work already',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'watching telugu movie wat abt u',
#  'i see when we finish we have load of loan to pay',
#  'hi wk been ok on hols now yes on for a bit of a run forgot that i have hairdresser appointment at four so need to get home n shower beforehand doe that cause prob for u',
#  'i see a cup of coffee animation',
#  'please don t text me anymore i have nothing else to say',
#  'okay name ur price a long a it legal wen can i pick them up y u ave x am xx',
#  'i m still looking for a car to buy and have not gone the driving test yet',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'wow you re right i didn t mean to do that i guess once i gave up on boston men and changed my search location to nyc something changed cuz on my signin page it still say boston',
#  'umma my life and vava umma love you lot dear',
#  'thanks a lot for your wish on my birthday thanks you for making my birthday truly memorable',
#  'aight i ll hit you up when i get some cash',
#  'how would my ip address test that considering my computer isn t a minecraft server',
#  'i know grumpy old people my mom wa like you better not be lying then again i am always the one to play joke',
#  'dont worry i guess he s busy',
#  'what is the plural of the noun research',
#  'going for dinner msg you after',
#  'i m ok wif it co i like try new thing but i scared u dun like mah co u said not too loud',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'wa ur openin sentence very formal anyway i m fine too juz tt i m eatin too much n puttin on weight haha so anythin special happened',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'you are a winner u have been specially selected receive or a holiday flight inc speak to a live operator claim p min',
#  'goodo yes we must speak friday egg potato ratio for tortilla needed',
#  'hmm my uncle just informed me that he s paying the school directly so pls buy food',
#  'private your account statement for show unredeemed bonus point to claim call identifier code expires',
#  'urgent your mobile no wa awarded bonus caller prize on this is our final try to contact u call from landline box wr c ppm',
#  'here is my new address apple pair all that malarky',
#  'today voda number ending are selected to receive a award if you have a match please call quoting claim code standard rate app',
#  'i am going to sao mu today will be done only at',
#  'predict wat time ll finish buying',
#  'good stuff will do',
#  'just so that you know yetunde hasn t sent money yet i just sent her a text not to bother sending so it over you dont have to involve yourself in anything i shouldn t have imposed anything on you in the first place so for that i apologise',
#  'are you there in room',
#  'hey girl how r u hope u r well me an del r bak again long time no c give me a call sum time from lucyxx',
#  'k k how much doe it cost',
#  'i m home',
#  'dear will call tmorrow pls accomodate',
#  'first answer my question',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country the algarve is in txt ansr to sp tyrone',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network bt txting gravel to nt ec a p msg p',
#  'i only haf msn it s yijue hotmail com',
#  'he is there you call and meet him',
#  'no no i will check all room befor activity',
#  'you ll not rcv any more msg from the chat svc for free hardcore service text go to if u get nothing u must age verify with yr network try again',
#  'got c i lazy to type i forgot in lect i saw a pouch but like not v nice',
#  'k text me when you re on the way',
#  'sir waiting for your mail',
#  'a swt thought nver get tired of doing little thing lovable person coz somtimes those little thing occupy d biggest part in their heart gud ni',
#  'i know you are can you pls open the back',
#  'yes see ya not on the dot',
#  'whats the staff name who is taking class for u',
#  'freemsg why haven t you replied to my text i m randy sexy female and live local luv to hear from u netcollex ltd p per msg reply stop to end',
#  'ummma will call after check in our life will begin from qatar so pls pray very hard',
#  'k i deleted my contact that why',
#  'sindu got job in birla soft',
#  'the wine is flowing and i m i have nevering',
#  'yup i thk cine is better co no need go down plaza mah',
#  'ok ur typical reply',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'you are everywhere dirt on the floor the window even on my shirt and sometimes when i open my mouth you are all that come flowing out i dream of my world without you then half my chore are out too a time of joy for me lot of tv show i ll see but i guess like all thing you just must exist like rain hail and mist and when my time here is done you and i become one',
#  'aaooooright are you at work',
#  'i m leaving my house now',
#  'hello my love what are you doing did you get to that interview today are you you happy are you being a good boy do you think of me are you missing me',
#  'customer service annoncement you have a new year delivery waiting for you please call now to arrange delivery',
#  'you are a winner u have been specially selected receive cash or a holiday flight inc speak to a live operator claim',
#  'keep yourself safe for me because i need you and i miss you already and i envy everyone that see s you in real life',
#  'new car and house for my parent i have only new job in hand',
#  'i m so in love with you i m excited each day i spend with you you make me so happy',
#  'pls stop bootydelious f is inviting you to be her friend reply yes or no see her www sm ac u bootydelious stop send stop frnd to',
#  'bangbabes ur order is on the way u should receive a service msg download ur content if u do not goto wap bangb tv on ur mobile internet service menu',
#  'i place all ur point on e culture module already',
#  'urgent we are trying to contact you last weekend draw show that you have won a prize guaranteed call claim code s valid hr only',
#  'hi frnd which is best way to avoid missunderstding wit our beloved one s',
#  'great escape i fancy the bridge but need her lager see you tomo',
#  'yes it completely in out of form clark also utter waste',
#  'sir i need axis bank account no and bank address',
#  'hmmm thk sure got time to hop ard ya can go free abt muz call u to discus liao',
#  'what time you coming down later',
#  'bloody hell cant believe you forgot my surname mr ill give u a clue it spanish and begin with m',
#  'well i m gonna finish my bath now have a good fine night',
#  'let me know when you ve got the money so carlos can make the call',
#  'u still going to the mall',
#  'turn out my friend are staying for the whole show and won t be back til lt gt so feel free to go ahead and smoke that lt gt worth',
#  'text her if she doesnt reply let me know so i can have her log in',
#  'hi you just spoke to maneesha v we d like to know if you were satisfied with the experience reply toll free with yes or no',
#  'you lifted my hope with the offer of money i am in need especially when the end of the month approach and it hurt my studying anyways have a gr weekend',
#  'lol no u can trust me',
#  'ok i am a gentleman and will treat you with dignity and respect',
#  'he will you guy close',
#  'going on nothing great bye',
#  'hello handsome are you finding that job not being lazy working towards getting back that net for mummy where s my boytoy now doe he miss me',
#  'haha awesome be there in a minute',
#  'please call our customer service representative on freephone between am pm a you have won a guaranteed cash or prize',
#  'have you got xmas radio time if not i will get it now',
#  'i jus reached home i go bathe first but my si using net tell u when she finish k',
#  'are you unique enough find out from th august www areyouunique co uk',
#  'i m sorry i ve joined the league of people that dont keep in touch you mean a great deal to me you have been a friend at all time even at great personal cost do have a great week',
#  'hi finally i completed the course',
#  'it will stop on itself i however suggest she stay with someone that will be able to give or for every stool',
#  'how are you doing hope you ve settled in for the new school year just wishin you a gr day',
#  'gud mrng dear hav a nice day',
#  'did u got that person story',
#  'is your hamster dead hey so tmr i meet you at pm orchard mrt',
#  'hi it kate how is your evening i hope i can see you tomorrow for a bit but i have to bloody babyjontet txt back if u can xxx',
#  'found it enc lt gt where you at',
#  'i sent you lt gt buck',
#  'hello darlin ive finished college now so txt me when u finish if u can love kate xxx',
#  'your account ha been refilled successfully by inr lt decimal gt your keralacircle prepaid account balance is r lt decimal gt your transaction id is kr lt gt',
#  'goodmorning sleeping ga',
#  'u call me alter at ok',
#  'say until like dat i dun buy ericsson oso cannot oredi lar',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'aight yo dat straight dogg',
#  'you please give u connection today itself before lt decimal gt or refund the bill',
#  'both i shoot big load so get ready',
#  'what s up bruv hope you had a great break do have a rewarding semester',
#  'home so we can always chat',
#  'k k good study well',
#  'yup how noe leh',
#  'sound great are you home now',
#  'finally the match heading towards draw a your prediction',
#  'tired i haven t slept well the past few night',
#  'easy ah sen got selected mean it good',
#  'i have to take exam with march',
#  'yeah you should i think you can use your gt atm now to register not sure but if there s anyway i can help let me know but when you do be sure you are ready',
#  'ok no prob take ur time',
#  'there is o called ubandu which will run without installing in hard disk you can use that o to copy the important file in system and give it to repair shop',
#  'sorry i ll call later',
#  'u say leh of course nothing happen lar not say v romantic jus a bit only lor i thk e nite scenery not so nice leh',
#  'new mobile from must go txt nokia to no collect yours today from only www tc biz optout gbp mtmsg',
#  'would really appreciate if you call me just need someone to talk to',
#  'will u meet ur dream partner soon is ur career off a flyng start find out free txt horo followed by ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life is more strict than teacher bcoz teacher teach lesson amp then conduct exam but life first conduct exam amp then teach lesson happy morning',
#  'dear good morning now only i am up',
#  'get down in gandhipuram and walk to cross cut road right side lt gt street road and turn at first right',
#  'dear we are going to our rubber place',
#  'sorry battery died yeah i m here',
#  'yes here tv is always available in work place',
#  'text meet someone sexy today u can find a date or even flirt it up to u join just p reply with name age eg sam msg recd thirtyeight penny',
#  'i have printed it oh so lt gt come upstairs',
#  'or ill be a little closer like at the bus stop on the same street',
#  'where are you when wil you reach here',
#  'new theory argument win d situation but loses the person so dont argue with ur friend just kick them amp say i m always correct',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'tomarrow final hearing on my laptop case so i cant',
#  'pleassssssseeeeee tel me v avent done sportsx',
#  'okay no no just shining on that wa meant to be signing but that sound better',
#  'although i told u dat i m into baig face watch now but i really like e watch u gave co it s fr u thanx everything dat u ve done today i m touched',
#  'u don t remember that old commercial',
#  'too late i said i have the website i didn t i have or dont have the slipper',
#  'i asked you to call him now ok',
#  'kallis wont bat in nd inning',
#  'it didnt work again oh ok goodnight then i ll fix and have it ready by the time you wake up you are very dearly missed have a good night sleep',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ranjith cal drpd deeraj and deepak min hold',
#  'wen ur lovable bcums angry wid u dnt take it seriously coz being angry is d most childish n true way of showing deep affection care n luv kettoda manda have nice day da',
#  'what you doing how are you',
#  'ups which is day also and the shipping company that take wks the other way is usps which take a week but when it get to lag you may have to bribe nipost to get your stuff',
#  'i m back lemme know when you re ready',
#  'don t necessarily expect it to be done before you get back though because i m just now headin out',
#  'mmm so yummy babe nice jolt to the suzy',
#  'where are you lover i need you',
#  'we tried to contact you re your reply to our offer of a video handset anytime network min unlimited text camcorder reply or call now',
#  'i m parked next to a mini when are you coming in today do you think',
#  'yup',
#  'anyway i m going shopping on my own now co my si not done yet dun disturb u liao',
#  'my no in luton ring me if ur around h',
#  'hey i am really horny want to chat or see me naked text hot to text charged at pm to unsubscribe text stop',
#  'why you dint come with u',
#  'same wana plan a trip sometme then',
#  'not sure yet still trying to get a hold of him',
#  'ur ringtone service ha changed free credit go to club mobile com to choose content now stop txt club stop to p wk club po box mk wt',
#  'the evo i just had to download flash jealous',
#  'ringtone club get the uk single chart on your mobile each week and choose any top quality ringtone this message is free of charge',
#  'come to mu we re sorting out our narcotic situation',
#  'night ha ended for another day morning ha come in a special way may you smile like the sunny ray and leaf your worry at the blue blue bay',
#  'hmv bonus special pound of genuine hmv voucher to be won just answer easy question play now send hmv to more info www percent real com',
#  'usf i guess might a well take car',
#  'no objection my bf not coming',
#  'thanx',
#  'tell rob to mack his gf in the theater',
#  'awesome i ll see you in a bit',
#  'just sent it so what type of food do you like',
#  'all done all handed in celebration in full swing yet',
#  'you got called a tool',
#  'wen u miss someone the person is definitely special for u but if the person is so special why to miss them just keep in touch gdeve',
#  'ok i asked for money how far',
#  'okie',
#  'yeah i think my usual guy s still passed out from last night if you get ahold of anybody let me know and i ll throw down',
#  'k i might come by tonight then if my class let out early',
#  'ok',
#  'hi baby im cruisin with my girl friend what r u up give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx',
#  'my life mean a lot to me not because i love my life but because i love the people in my life the world call them friend i call them my world ge',
#  'dear shall mail tonite busy in the street shall update you tonite thing are looking ok varunnathu edukkukayee raksha ollu but a good one in real sense',
#  'hey you told your name to gautham ah',
#  'haf u found him i feel so stupid da v cam wa working',
#  'oops got that bit',
#  'are you this much buzy',
#  'i accidentally deleted the message resend please',
#  't mobile customer you may now claim your free camera phone upgrade a pay go sim card for your loyalty call on offer end thfeb t c s apply',
#  'unless it s a situation where you go gurl would be more appropriate',
#  'hurt me tease me make me cry but in the end of my life when i die plz keep one rose on my grave and say stupid i miss u have a nice day bslvyl',
#  'i cant pick the phone right now pls send a message',
#  'need a coffee run tomo can t believe it s that time of week already',
#  'awesome i remember the last time we got somebody high for the first time with diesel v',
#  'shit that is really shocking and scary cant imagine for a second def up for night out do u think there is somewhere i could crash for night save on taxi',
#  'oh and by the way you do have more food in your fridge want to go out for a meal tonight',
#  'he is a womdarfull actor',
#  'sm ac blind date u rodds is m from aberdeen united kingdom check him out http img sm ac w icmb cktz r no blind date send hide',
#  'yup from what i remb i think should be can book',
#  'jos ask if u wana meet up',
#  'lol yes our friendship is hanging on a thread cause u won t buy stuff',
#  'themob check out our newest selection of content game tone gossip babe and sport keep your mobile fit and funky text wap to',
#  'where are the garage key they aren t on the bookshelf',
#  'today is accept day u accept me a brother sister lover dear best clos lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rply mean enemy',
#  'think ur smart win this week in our weekly quiz text play to now t c winnersclub po box m uz gbp week',
#  'he say he ll give me a call when his friend s got the money but that he s definitely buying before the end of the week',
#  'hi the way i wa with u day is the normal way this is the real me ur unique i hope i know u the rest of mylife hope u find wot wa lost',
#  'you made my day do have a great day too',
#  'k k advance happy pongal',
#  'hmmm guess we can go kb n power yoga haha dunno we can tahan power yoga anot thk got lo oso forgot liao',
#  'not really dude have no friend i m afraid',
#  'december only had your mobile mths you are entitled to update to the latest colour camera mobile for free call the mobile update co free on',
#  'coffee cake i guess',
#  'merry christmas to you too babe i love ya kiss',
#  'hey why dont we just go watch x men and have lunch haha',
#  'cud u tell ppl im gona b a bit l co bus hav gon past co they were full im still waitin pete x',
#  'that would be great we ll be at the guild could meet on bristol road or somewhere will get in touch over weekend our plan take flight have a good week',
#  'no problem how are you doing',
#  'no call message missed call',
#  'hi da how is the today class',
#  'i d say that s a good sign but well you know my track record at reading woman',
#  'cool text me when you re parked',
#  'i m reading the text i just sent you it meant to be a joke so read it in that light',
#  'k k apo k good movie',
#  'maybe i could get book out tomo then return it immediately or something',
#  'call germany for only penny per minute call from a fixed line via access number no prepayment direct access',
#  'any chance you might have had with me evaporated a soon a you violated my privacy by stealing my phone number from your employer s paperwork not cool at all please do not contact me again or i will report you to your supervisor',
#  'valentine day special win over in our quiz and take your partner on the trip of a lifetime send go to now p msg rcvd custcare',
#  'ta daaaaa i am home babe are you still up',
#  'cool so how come you havent been wined and dined before',
#  'just sleeping and surfing',
#  'sorry i ll call later',
#  'u calling me right call my hand phone',
#  'ok that s great thanx a lot',
#  'i take it the post ha come then you must have s of text now happy reading my one from wiv hello caroline at the end is my favourite bless him',
#  'where u been hiding stranger',
#  'am not interested to do like that',
#  'my sister cleared two round in birla soft yesterday',
#  'gudnite tc practice going on',
#  'dis is yijue i jus saw ur mail in case huiming havent sent u my num dis is my num',
#  'one small prestige problem now',
#  'fancy a shag i do interested sextextuk com txt xxuk suzy to txts cost per msg tncs on website x',
#  'just checking in on you really do miss seeing jeremiah do have a great month',
#  'nah can t help you there i ve never had an iphone',
#  'if you re not in my car in an hour and a half i m going apeshit',
#  'today is sorry day if ever i wa angry with you if ever i misbehaved or hurt you plz plz just slap urself bcoz it ur fault i m basically good',
#  'yo you guy ever figure out how much we need for alcohol jay and i are trying to figure out how much we can safely spend on weed',
#  'lt gt ish minute wa minute ago wtf',
#  'thank you for calling forgot to say happy onam to you sirji i am fine here and remembered you when i met an insurance person meet you in qatar insha allah rakhesh ex tata aig who joined tissco tayseer',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ur cash balance is currently pound to maximize ur cash in now send cash to only p msg cc hg suite land row w j hl',
#  'i m an actor when i work i work in the evening and sleep late since i m unemployed at the moment i always sleep late when you re unemployed every day is saturday',
#  'hello just got here st andrew boy it a long way it cold i will keep you posted',
#  'ha ha cool cool chikku chikku db',
#  'oh ok no prob',
#  'check audrey s status right now',
#  'busy here trying to finish for new year i am looking forward to finally meeting you',
#  'good afternoon sunshine how dawn that day are we refreshed and happy to be alive do we breathe in the air and smile i think of you my love a always',
#  'well i know z will take care of me so no worry',
#  'update now xmas offer latest motorola sonyericsson nokia free bluetooth double min txt on orange call mobileupd on or call optout f q',
#  'here is your discount code rp to stop further message reply stop www regalportfolio co uk customer service',
#  'wat uniform in where get',
#  'cool text me when you re ready',
#  'hello my boytoy geeee i miss you already and i just woke up i wish you were here in bed with me cuddling me i love you',
#  'i will spoil you in bed a well',
#  'i m going for bath will msg you next lt gt min',
#  'i cant keep talking to people if am not sure i can pay them if they agree to price so pls tell me what you want to really buy and how much you are willing to pay',
#  'thanks for your ringtone order reference t you will be charged gbp per week you can unsubscribe at anytime by calling customer service on',
#  'can you say what happen',
#  'you could have seen me i did t recognise you face',
#  'well there s not a lot of thing happening in lindsay on new year sigh some bar in ptbo and the blue heron ha something going',
#  'keep my payasam there if rinu brings',
#  'i taught that ranjith sir called me so only i sm like that becaus he verifying about project prabu told today so only pa dont mistake me',
#  'i guess that s why you re worried you must know that there s a way the body repair itself and i m quite sure you shouldn t worry we ll take it slow first the test they will guide when your ovulation is then just relax nothing you ve said is a reason to worry but i ll keep on followin you up',
#  'yeah sure give me a couple minute to track down my wallet',
#  'hey leave it not a big deal take care',
#  'hey i will be late ah meet you at',
#  'double min and txts month free bluetooth on orange available on sony nokia motorola phone call mobileupd on or call optout n dx',
#  'it took mr owl lick',
#  'customer place i will call you',
#  'mm that time you dont like fun',
#  'mths half price orange line rental latest camera phone free had your phone mths call mobilesdirect free on to update now or stoptxt',
#  'yup having my lunch buffet now u eat already',
#  'huh so late fr dinner',
#  'hey so this sat are we going for the intro pilate only or the kickboxing too',
#  'morning only i can ok',
#  'yes i think so i am in office but my lap is in room i think thats on for the last few day i didnt shut that down',
#  'pick you up bout ish what time are and that going',
#  'from here after the performance award is calculated every two month not for current one month period',
#  'wa actually sleeping and still might when u call back so a text is gr you rock si will send u a text wen i wake',
#  'you are always putting your business out there you put picture of your as on facebook you are one of the most open people i ve ever met why would i think a picture of your room would hurt you make you feel violated',
#  'good evening sir al salam wahleykkum sharing a happy news by the grace of god i got an offer from tayseer tissco and i joined hope you are fine inshah allah meet you sometime rakhesh visitor from india',
#  'hmmm k but i want to change the field quickly da i wanna get system administrator or network administrator',
#  'free ringtone text first to for a poly or text get to for a true tone help after st free tone are x pw to e nd txt stop',
#  'dear how is chechi did you talk to her',
#  'the hair cream ha not been shipped',
#  'none of that s happening til you get here though',
#  'yep the great loxahatchee xmas tree burning of lt gt start in an hour',
#  'haha get used to driving to usf man i know a lot of stoner',
#  'all wa well until slightly disastrous class this pm with my fav darling hope day off ok coffee wld be good a can t stay late tomorrow same time place a always',
#  'hello good week fancy a drink or something later',
#  'headin towards busetop',
#  'message some text missing sender name missing number missing sent date missing missing u a lot thats y everything is missing sent via fullonsms com',
#  'come by our room at some point so we can iron out the plan for this weekend',
#  'co i want it to be your thing',
#  'okies i ll go yan jiu too we can skip ard oso go cine den go mrt one blah blah blah',
#  'bring home some wendy d',
#  'dating service cal l box sk ch',
#  'whatsup there dont u want to sleep',
#  'alright i have a new goal now',
#  'free entry into our weekly competition just text the word win to now t c www txttowin co uk',
#  'alright i ll head out in a few minute text me where to meet you',
#  'send a logo ur lover name joined by a heart txt love name name mobno eg love adam eve to yahoo pobox w wq txtno no ad p',
#  'yes from last week itself i m taking live call',
#  'someone ha contacted our dating service and entered your phone because they fancy you to find out who it is call from a landline pobox n tf p',
#  'siva is in hostel aha',
#  'urgent your mobile number ha been awarded with a prize guaranteed call from land line claim valid hr only',
#  'send this to ur friend and receive something about ur voice how is my speaking expression childish naughty sentiment rowdy ful of attitude romantic shy attractive funny lt gt irritating lt gt lovable reply me',
#  'ok she ll be ok i guess',
#  'aathi where are you dear',
#  'any pain on urination any thing else',
#  'at esplanade do mind giving me a lift co i got no car today',
#  'i wnt to buy a bmw car urgently it vry urgent but hv a shortage of lt gt lac there is no source to arng dis amt lt gt lac thats my prob',
#  'at home watching tv lor',
#  'doe she usually take fifteen fucking minute to respond to a yes or no question',
#  'congrats nokia video camera phone is your call call cost ppm ave call min vary from mobile close post bcm ldn wc n xx',
#  'booked ticket for pongal',
#  'you available now i m like right around hillsborough amp lt gt th',
#  'the message sent is askin for lt gt dollar shoul i pay lt gt or lt gt',
#  'ask g or iouri i ve told the story like ten time already',
#  'how long doe applebees fucking take',
#  'hi hope u get this txt journey hasnt been gd now about min late i think',
#  'but i have to i like to have love and arrange',
#  'yes he is really great bhaji told kallis best cricketer after sachin in world very tough to get out',
#  'you were supposed to wake me up gt',
#  'oic i saw him too but i tot he din c me i found a group liao',
#  'sorry i ll call later',
#  'hey hey werethe monkeespeople say we monkeyaround howdy gorgeous howu doin foundurself a jobyet sausage love jen xxx',
#  'sorry my battery died i can come by but i m only getting a gram for now where s your place',
#  'well done blimey exercise yeah i kinda remember wot that is hmm',
#  'i wont get concentration dear you know you are my mind and everything',
#  'lol have you made plan for new year',
#  'min later k',
#  'hank lotsly',
#  'thanks for this hope you had a good day today',
#  'k k what are detail you want to transfer acc no enough',
#  'ok i will tell her to stay out yeah it been tough but we are optimistic thing will improve this month',
#  'loan for any purpose homeowner tenant welcome have you been previously refused we can still help call free or text back help',
#  'si si i think ill go make those oreo truffle',
#  'look at amy ure a beautiful intelligent woman and i like u a lot i know u don t like me like that so don t worry',
#  'i hope you that s the result of being consistently intelligent and kind start asking him about practicum link and keep your ear open and all the best ttyl',
#  'that call cost which i guess isnt bad miss ya need ya want ya love ya',
#  'going thru a very different feeling wavering decision and coping up with the same is the same individual time will heal everything i believe',
#  'where did u go my phone is gonna die you have to stay in here',
#  'great never been better each day give even more reason to thank god',
#  'upgrdcentre orange customer you may now claim your free camera phone upgrade for your loyalty call now on offer end th july t c s apply opt out available',
#  'sorry i ll call later ok bye',
#  'ok i am on the way to railway',
#  'great princess i love giving and receiving oral doggy style is my fave position how about you i enjoy making love lt gt time per night',
#  'they don t put that stuff on the road to keep it from getting slippery over there',
#  'when are you going to ride your bike',
#  'yup no need i ll jus wait e rain stop',
#  'there are many company tell me the language',
#  'okmail dear dave this is your final notice to collect your tenerife holiday or cash award call from landline tc sae box cw wx ppm',
#  'how long ha it been since you screamed princess',
#  'nothing i meant that once the money enters your account here the bank will remove it flat rate someone transfered lt gt to my account and lt gt dollar got removed so the bank differ and charge also differ be sure you trust the ja person you are sending account detail to co',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network by txting moan to nyt ec a p msg p',
#  'nice line said by a broken heart plz don t cum more time infront of me other wise once again i ll trust u good t',
#  'ok i m gonna head up to usf in like fifteen minute',
#  'love you aathi love u lot',
#  'tension ah what machi any problem',
#  'k can i pick up another th when you re done',
#  'when re you guy getting back g said you were thinking about not staying for mcr',
#  'almost there see u in a sec',
#  'yo carlos a few friend are already asking me about you you working at all this weekend',
#  'watching tv lor',
#  'thank you baby i cant wait to taste the real thing',
#  'you should change your fb to jaykwon thuglyfe falconerf',
#  'if we win it really no side for long time',
#  'free message activate your free text message by replying to this message with the word free for term condition visit www com',
#  'dear reached railway what happen to you',
#  'depends on quality if you want the type i sent boye faded glory then about if you want ralphs maybe',
#  'i think i ve fixed it can you send a test message',
#  'sorry man my account s dry or i would if you want we could trade back half or i could buy some shit with my credit card',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry in meeting i ll call later',
#  'what class of lt gt reunion',
#  'are you free now can i call now',
#  'got meh when',
#  'nope think i will go for it on monday sorry i replied so late',
#  'some of them told accenture is not confirm is it true',
#  'kate jackson rec center before ish right',
#  'dear i have reache room',
#  'fighting with the world is easy u either win or lose bt fightng with some who is close to u is dificult if u lose u lose if u win u still lose',
#  'when can come out',
#  'check with nuerologist',
#  'lolnice i went from a fish to water',
#  'congratulation in this week s competition draw u have won the prize to claim just call b t c stop sm over only ppm',
#  'no it s waiting in e car dat s bored wat co wait outside got nothing do at home can do my stuff or watch tv wat',
#  'maybe westshore or hyde park village the place near my house',
#  'you should know now so how s anthony are you bringing money i ve school fee to pay and rent and stuff like that thats why i need your help a friend in need',
#  'what s the significance',
#  'your opinion about me over jada kusruthi lovable silent spl character not matured stylish simple pls reply',
#  'at the latest g s still there if you can scrounge up some ammo and want to give the new ak a try',
#  'prabha i m soryda realy frm heart i m sory',
#  'lol ok your forgiven',
#  'no jst change tat only',
#  'you are guaranteed the latest nokia phone a gb ipod mp player or a prize txt word collect to no ibhltd ldnw h p mtmsgrcvd',
#  's no competition for him',
#  'boltblue tone for p reply poly or mono eg poly cha cha slide yeah slow jamz toxic come with me or stop more tone txt more',
#  'your credit have been topped up for http www bubbletext com your renewal pin is tgxxrz',
#  'that way transport is le problematic than on sat night by the way if u want to ask n to join my bday feel free but need to know definite no a booking on fri',
#  'usually the person is unconscious that s in child but in adult they may just behave abnormally i ll call you now',
#  'but that s on ebay it might be le elsewhere',
#  'shall i come to get pickle',
#  'were gonna go get some taco',
#  'that s very rude you on campus',
#  'urgent your mobile no wa awarded a bonus caller prize on this is our nd attempt to contact you call box qu',
#  'hi i won t b ard christmas but do enjoy n merry x ma',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'yes how is a pretty lady like you single',
#  'you will recieve your tone within the next hr for term and condition please see channel u teletext pg',
#  'jay say that you re a double faggot',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'what today sunday sunday is holiday so no work',
#  'gudnite tc practice going on',
#  'i ll be late',
#  'i ve not called you in a while this is hoping it wa l r malaria and that you know that we miss you guy i miss ban big so pls give her my love especially have a great day',
#  'good afternoon my love how go that day i hope maybe you got some lead on a job i think of you boytoy and send you a passionate kiss from across the sea',
#  'probably gonna be here for a while see you later tonight lt',
#  'or maybe my fat finger just press all these button and it doesn t know what to do',
#  'ummmmmaah many many happy return of d day my dear sweet heart happy birthday dear',
#  'i am in tirupur da once you started from office call me',
#  'from www applausestore com monthlysubscription p msg max month t csc web age stop txt stop',
#  'a famous quote when you develop the ability to listen to anything unconditionally without losing your temper or self confidence it mean you are married',
#  'but am going to college pa what to do are else ill come there it self pa',
#  'oclock at mine just to bash out a flat plan',
#  'this girl doe not stay in bed this girl doesn t need recovery time id rather pas out while having fun then be cooped up in bed',
#  'then any special there',
#  'i know but you need to get hotel now i just got my invitation but i had to apologise cali is to sweet for me to come to some english bloke s weddin',
#  'sorry that took so long omw now',
#  'wait lt gt min',
#  'ok give me minute i think i see her btw you re my alibi you were cutting my hair the whole time',
#  'imagine you finally get to sink into that bath after i have put you through your pace maybe even having you eat me for a while before i left but also imagine the feel of that cage on your cock surrounded by the bath water reminding you always who owns you enjoy my cuck',
#  'hurry up i ve been weed deficient for like three day',
#  'sure if i get an acknowledgement from you that it s astoundingly tactless and generally faggy to demand a blood oath fo',
#  'ok every night take a warm bath drink a cup of milk and you ll see a work of magic you still need to loose weight just so that you know',
#  'i ll have a look at the frying pan in case it s cheap or a book perhaps no that s silly a frying pan isn t likely to be a book',
#  'o well uv cause mutation sunscreen is like essential thesedays',
#  'having lunch you are not in online why',
#  'i know that my friend already told that',
#  'hi princess thank you for the pic you are very pretty how are you',
#  'aiyo u always c our ex one i dunno abt mei she haven reply first time u reply so fast y so lucky not workin huh got bao by ur sugardad ah gee',
#  'hi msg me i m in office',
#  'thanx e brownie it s v nice',
#  'geeeee i love you so much i can barely stand it',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'fuck babe i miss you already you know can t you let me send you some money towards your net i need you i want you i crave you',
#  'ill call u mrw at ninish with my address that icky american freek wont stop callin me bad jen k eh',
#  'oooh bed ridden ey what are you thinking of',
#  'so anyways you can just go to your gym or whatever my love smile i hope your ok and having a good day babe i miss you so much already',
#  'love it daddy will make you scream with pleasure i am going to slap your as with my dick',
#  'wot u wanna do then missy',
#  'yar lor wait my mum finish sch then have lunch lor i whole morning stay at home clean my room now my room quite clean hee',
#  'do you know where my lab goggles went',
#  'can you open the door',
#  'waiting for your call',
#  'nope i waiting in sch daddy',
#  'you have won cash or a prize to claim call',
#  'i m tired of arguing with you about this week after week do what you want and from now on i ll do the same',
#  'wait me in sch i finish ard',
#  'our mobile number ha won to claim call u back or ring the claim hot line on',
#  'arngd marriage is while u r walkin unfortuntly a snake bite u bt love marriage is dancing in frnt of d snake amp sayin bite me bite me',
#  'huh so early then having dinner outside izzit',
#  'ok anyway no need to change with what you said',
#  'we tried to contact you re your reply to our offer of min textand a new video phone call now or reply for free delivery tomorrow',
#  'my ex wife wa not able to have kid do you want kid one day',
#  'so how s scotland hope you are not over showing your jjc tendency take care live the dream',
#  'tell them u have a headache and just want to use hour of sick time',
#  'i dun thk i ll quit yet hmmm can go jazz yogasana oso can we can go meet em after our lesson den',
#  'pete can you please ring meive hardly gotany credit',
#  'ya srsly better than yi tho',
#  'i m in a meeting call me later at',
#  'for ur chance to win a wkly shopping spree txt shop to t s c s www txt shop com custcare x p wk',
#  'you have been specially selected to receive a pound award call before the line close cost ppm t c apply ag promo',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'you still at grand prix',
#  'i met you a a stranger and choose you a my friend a long a the world stand our friendship never end let be friend forever gud nitz',
#  'i am great how are you',
#  'gud mrng dear have a nice day',
#  'you have an important customer service announcement call freephone now',
# ...
#  'i borrow ur bag ok',
#  'u were outbid by simonwatson on the shinco dvd plyr bid again visit sm ac smsrewards end bid notification reply end out',
#  'where s my boytoy i miss you what happened',
#  'he ha lot of used one babe but the model doesn t help youi have to bring it over and he ll match it up',
#  'also are you bringing galileo or dobby',
#  'then why you not responding',
#  'boo babe u enjoyin yourjob u seemed b gettin on well hunny hope ure ok take care i llspeak u soonlots of loveme xxxx',
#  'good afternoon starshine how s my boytoy doe he crave me yet ache to fuck me sip cappuccino i miss you babe teasing kiss',
#  'on the road so cant txt',
#  'smsservices for yourinclusive text credit pls goto www comuk net login qxj unsubscribe with stop no extra charge help comuk cm ae',
#  'p alfie moon s child in need song on ur mob tell ur m s txt tone charity to for nokias or poly charity for polys zed profit charity',
#  'have a good evening ttyl',
#  'hmm bit and piece lol sigh',
#  'hahaha use your brain dear',
#  'hey you got any mail',
#  'sorry light turned green i meant another friend wanted lt gt worth but he may not be around',
#  'thanks for yesterday sir you have been wonderful hope you enjoyed the burial mojibiola',
#  'u have a secret admirer reveal who think u r so special call to opt out reply reveal stop per msg recd cust care',
#  'hi mate it rv did u hav a nice hol just a message say hello coz haven t sent u in age started driving so stay off road rvx',
#  'dear voucher holder to claim this week offer at you pc please go to http www e tlp co uk expressoffer t c apply to stop text txt stop to',
#  'thank you so much when we skyped wit kz and sura we didnt get the pleasure of your company hope you are good we ve given you ultimatum oh we are countin down to aburo enjoy this is the message i sent day ago',
#  'surely result will offer',
#  'good morning my dear have a great amp successful day',
#  'do you want anytime any network min text and a new video phone for only five pound per week call or reply for delivery tomorrow',
#  'sir i have been late in paying rent for the past few month and had to pay a lt gt charge i felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that s why i didnt speak up i however am in a recession and wont be able to pay the charge this month hence my askin well ahead of month s end can you please help thanks',
#  'we tried to contact you re our offer of new video phone anytime any network min half price rental camcorder call or reply for delivery wed',
#  'last chance claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub remove txt x or stop',
#  'i luv u soo much u don t understand how special u r me ring u morrow luv u xxx',
#  'pls send me a comprehensive mail about who i m paying when and how much',
#  'our prashanthettan s mother passed away last night pray for her and family',
#  'urgent call from your landline your complimentary ibiza holiday or cash await collection sae t c po box sk wp ppm',
#  'k k when are you going',
#  'meanwhile in the shit suite xavier decided to give u lt gt second of warning that samantha wa coming over and is playing jay s guitar to impress her or some shit also i don t think doug realizes i don t live here anymore',
#  'my stomach ha been thru so much trauma i swear i just can t eat i better lose weight',
#  'i am in office whats the matter msg me now i will call you at break',
#  'yeah there s barely enough room for the two of u x ha too many fucking shoe sorry man see you later',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'u reach orchard already u wan go buy ticket first',
#  'i am real baby i want to bring out your inner tigress',
#  'no da if you run that it activate the full version da',
#  'ah poor baby hope urfeeling bettersn luv probthat overdose of work hey go careful spk u sn lot of lovejen xxx',
#  'stop the story i ve told him i ve returned it and he s saying i should not re order it',
#  'talk sexy make new friend or fall in love in the world most discreet text dating service just text vip to and see who you could meet',
#  'going to take your babe out',
#  'hai ana tomarrow am coming on morning lt decimal gt ill be there in sathy then we ll go to rto office reply me after came to home',
#  'spoon it is then okay',
#  'did he just say somebody is named tampa',
#  'in work now going have in few min',
#  'your brother is a genius',
#  'sorry i guess whenever i can get a hold of my connection maybe an hour or two i ll text you',
#  'did u find out what time the bus is at coz i need to sort some stuff out',
#  'dude ive been seeing a lotta corvette lately',
#  'congratulation ur awarded either a yr supply of cd from virgin record or a mystery gift guaranteed call t c www smsco net pm approx min',
#  'same here but i consider wall and bunker and shit important just because i never play on peaceful but i guess your place is high enough that it don t matter',
#  'private your account statement for xxxxxx show un redeemed s i m point call identifier code expires',
#  'hello we need some posh bird and chap to user trial prod for champneys can i put you down i need your address and dob asap ta r',
#  'what do u want for xmas how about free text message a new video phone with half price line rental call free now on to find out more',
#  'well am officially in a philosophical hole so if u wanna call am at home ready to be saved',
#  'it going good no problem but still need little experience to understand american customer voice',
#  'i ll text you when i drop x off',
#  'ugh it been a long day i m exhausted just want to cuddle up and take a nap',
#  'talk with yourself atleast once in a day otherwise you will miss your best friend in this world shakespeare shesil lt gt',
#  'shop till u drop is it you either k k cash or travel voucher call now ntt po box cr bt fixedline cost ppm mobile vary',
#  'are you in castor you need to see something',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country liverpool played in mid week txt ansr to sp tyrone',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on stopsms',
#  'reminder you have not downloaded the content you have already paid for goto http doit mymoby tv to collect your content',
#  'see i knew giving you a break a few time woul lead to you always wanting to miss curfew i wa gonna gibe you til one but a midnight movie is not gonna get out til after you need to come home you need to getsleep and if anything you need to b studdying ear training',
#  'i love to give massage i use lot of baby oil what is your fave position',
#  'dude we should go sup again',
#  'yoyyooo u know how to change permission for a drive in mac my usb flash drive',
#  'gibbs unsold mike hussey',
#  'i like to talk pa but am not able to i dont know y',
#  'y dun cut too short leh u dun like ah she failed she s quite sad',
#  'you unbelievable faglord',
#  'wife how she knew the time of murder exactly',
#  'why do you ask princess',
#  'i am great princess what are you thinking about me',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie you',
#  'it s ok i noe u re busy but i m really too bored so i msg u i oso dunno wat colour she choose me one',
#  'doesn t g have class early tomorrow and thus shouldn t be trying to smoke at lt gt',
#  'superb thought be grateful that u dont have everything u want that mean u still have an opportunity to be happier tomorrow than u are today',
#  'hope you are having a good week just checking in',
#  'i m used to it i just hope my agent don t drop me since i ve only booked a few thing this year this whole me in boston them in nyc wa an experiment',
#  'thursday night yeah sure thing we ll work it out then',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'probably money worry thing are coming due and i have several outstanding invoice for work i did two and three month ago',
#  'how is it possible to teach you and where',
#  'i wonder if your phone battery went dead i had to tell you i love you babe',
#  'lovely smell on this bus and it ain t tobacco',
#  'we re all getting worried over here derek and taylor have already assumed the worst',
#  'hey what s up charles sorry about the late reply',
#  'all the lastest from stereophonics marley dizzee racal libertine and the stroke win nookii game with flirt click themob wap bookmark or text wap to',
#  'i ll give her once i have it plus she said grinule greet you whenever we speak',
#  'white fudge oreo are in store',
#  'january male sale hot gay chat now cheaper call national rate from p min cheap to p min peak to stop text call p min',
#  'my love how come it took you so long to leave for zaher s i got your word on ym and wa happy to see them but wa sad you had left i miss you',
#  'i am sorry it hurt you',
#  'can t i feel nauseous i m so pissed i didn t eat any sweet all week cause today i wa planning to pig out i wa dieting all week and now i m not hungry',
#  'ok lor but not too early me still having project meeting now',
#  'call me da i am waiting for your call',
#  'i could ask carlos if we could get more if anybody else can chip in',
#  'wa actually about to send you a reminder today have a wonderful weekend',
#  'when people see my msg they think iam addicted to msging they are wrong bcoz they don t know that iam addicted to my sweet friend bslvyl',
#  'hey you gave them your photo when you registered for driving ah tmr wanna meet at yck',
#  'dont talk to him ever ok it my word',
#  'when u wana see it then',
#  'on ma way to school can you pls send me ashley s number',
#  'it shall be fine i have avalarr now will hollalater',
#  'she went to attend another two round today but still did t reach home',
#  'actually i deleted my old website now i m blogging at magicalsongs blogspot com',
#  'k wait chikku il send aftr lt gt min',
#  'but i m on a diet and i ate too many slice of pizza yesterday ugh i m always on a diet',
#  'k i will give my kvb acc detail',
#  'oh all have to come ah',
#  'money you r a lucky winner claim your prize text money over million to give away ppt x normal text rate box w t jy',
#  'i m really sorry i won t b able do this friday hope u can find an alternative hope yr term s going ok',
#  'congratulation ore mo owo re wa enjoy it and i wish you many happy moment to and fro wherever you go',
#  'so do you have samus shoulder yet',
#  'what time you think you ll have it need to know when i should be near campus',
#  'dear matthew please call from a landline your complimentary lux tenerife holiday or cash await collection ppm sae t c box sk xh',
#  'then dun wear jean lor',
#  'since when which side any fever any vomitin',
#  'k k are you in college',
#  'urgent call from landline your complimentary tenerife holiday or cash await collection sae t c box hp yf ppm',
#  'better made up for friday and stuffed myself like a pig yesterday now i feel bleh but at least it not writhing pain kind of bleh',
#  'no we sell it all so we ll have ton if coin then sell our coin to someone thru paypal voila money back in life pocket',
#  'theyre doing it to lot of place only hospital and medical place are safe',
#  'how about getting in touch with folk waiting for company just txt back your name and age to opt in enjoy the community p sm',
#  'and also i ve sorta blown him off a couple time recently so id rather not text him out of the blue looking for weed',
#  'i sent my score to sophas and i had to do secondary application for a few school i think if you are thinking of applying do a research on cost also contact joke ogunrinde her school is one me the le expensive one',
#  'i cant wait to see you how were the photo were useful',
#  'ur cash balance is currently pound to maximize ur cash in now send go to only p msg cc po box tcr w',
#  'hey i booked the kb on sat already what other lesson are we going for ah keep your sat night free we need to meet and confirm our lodging',
#  'chk in ur belovd m dict',
#  'is that what time you want me to come',
#  'awesome lemme know whenever you re around',
#  'shb b ok lor thanx',
#  'beautiful truth against gravity read carefully our heart feel light when someone is in it but it feel very heavy when someone leaf it good night',
#  'also remember to get dobby s bowl from your car',
#  'filthy story and girl waiting for your',
#  'sorry i now then c ur msg yar lor so poor thing but only one night tmr u ll have a brand new room sleep in',
#  'love isn t a decision it s a feeling if we could decide who to love then life would be much simpler but then le magical',
#  'welp apparently he retired',
#  'my sort code is and acc no is the bank is natwest can you reply to confirm i ve sent this to the right person',
#  'where',
#  'u sure u can t take any sick time',
#  'urgent we are trying to contact u today draw show that you have won a prize guaranteed call from land line claim m valid hr only',
#  'watching cartoon listening music amp at eve had to go temple amp church what about u',
#  'yo chad which gymnastics class do you wanna take the site say christian class is full',
#  'are you this much buzy',
#  'or better still can you catch her and let ask her if she can sell lt gt for me',
#  'i am not sure about night menu i know only about noon menu',
#  'what do u want when i come back a beautiful necklace a a token of my heart for you thats what i will give but only to my wife of my liking be that and see no one can give you that dont call me i will wait till i come',
#  'are you willing to go for aptitude class',
#  'it wont b until a trying sort house out is that ok',
#  'yar lor he wan go c horse racing today mah so eat earlier lor i ate chicken rice u',
#  'haha awesome omw back now then',
#  'yup i thk so until e shop close lor',
#  'what is your account number',
#  'eh u send wrongly lar',
#  'hey no i ad a crap nite wa borin without ya boggy with me u boring biatch thanx but u wait til nxt time il ave ya',
#  'ok i shall talk to him',
#  'dont hesitate you know this is the second time she ha had weakness like that so keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure it nothing',
#  'hey you can pay with salary de only lt gt',
#  'another month i need chocolate weed and alcohol',
#  'if he started searching he will get job in few day he have great potential and talent',
#  'reckon need to be in town by eightish to walk from carpark',
#  'congrats mobile g videophones r yours call now videochat wid your mate play java game dload polyph music noline rentl',
#  'look at the fuckin time what the fuck you think is up',
#  'yo guess what i just dropped',
#  'carlos say he ll be at mu in lt gt minute',
#  'i m in office now i will call you lt gt min',
#  'geeee i miss you already you know your all i can think about fuck i can t wait till next year when we will be together loving kiss',
#  'yun ah the ubi one say if wan call by tomorrow call look for irene ere only got bus ubi cres ubi tech park ph for st wkg day n',
#  'ugh gotta drive back to sd from la my butt is sore',
#  'th of july',
#  'hi im having the most relaxing time ever we have to get up at am every day wa the party good the other night i get home tomorrow at ish',
#  'up to wan come then come lor but i din c any stripe skirt',
#  'the xmas story is peace the xmas msg is love the xmas miracle is jesus hav a blessed month ahead amp wish u merry xmas',
#  'i can t i don t have her number',
#  'change again it s e one next to escalator',
#  'yetunde i m in class can you not run water on it to make it ok pls now',
#  'not a lot ha happened here feel very quiet beth is at her aunt and charlie is working lot just me and helen in at the mo how have you been',
#  'then wait me at bus stop aft ur lect lar if i dun c then i go get my car then come back n pick',
#  ...]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   'to',
#   'rcv'],
#  ['even',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   'they',
#   'treat',
#   'me',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward',
#   'to',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['had',
#   'your',
#   'mobile',
#   'month',
#   'or',
#   'more',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight',
#   've',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot',
#   'txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise',
#   'you',
#   'have',
#   'been',
#   'wonderful',
#   'and',
#   'blessing',
#   'at',
#   'all',
#   'time'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching', 'here'],
#  ['eh',
#   'remember',
#   'how',
#   'spell',
#   'his',
#   'name',
#   'yes',
#   'did',
#   'he',
#   'naughty',
#   'make',
#   'until',
#   'wet'],
#  ['fine',
#   'if',
#   'that',
#   'the',
#   'way',
#   'feel',
#   'that',
#   'the',
#   'way',
#   'it',
#   'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'the',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'my',
#   'lunch',
#   'then',
#   'go',
#   'str',
#   'down',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff',
#   'alright',
#   'no',
#   'way',
#   'can',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'sooner'],
#  ['just',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'suck',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'know',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['lol', 'your', 'always', 'so', 'convincing'],
#  ['did',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['ahhh',
#   'work',
#   'vaguely',
#   'remember',
#   'that',
#   'what',
#   'doe',
#   'it',
#   'feel',
#   'like',
#   'lol'],
#  ['wait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['yeah',
#   'he',
#   'got',
#   'in',
#   'at',
#   'and',
#   'wa',
#   'apologetic',
#   'had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that',
#   'till',
#   'but',
#   'we',
#   'won',
#   'go',
#   'there',
#   'not',
#   'doing',
#   'too',
#   'badly',
#   'cheer',
#   'you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['for',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did',
#   'quick',
#   'have',
#   'cuppa'],
#  ['thanks',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no',
#   'if',
#   'you',
#   'reply',
#   'no',
#   'you',
#   'will',
#   'not',
#   'be',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['oops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'how',
#   'you',
#   'and',
#   'how',
#   'did',
#   'saturday',
#   'go',
#   'wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo',
#   'not',
#   'that',
#   'trying',
#   'to',
#   'invite',
#   'myself',
#   'or',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'with',
#   'watt',
#   'just',
#   'wanted',
#   'to',
#   'be',
#   'sure',
#   'do',
#   'have',
#   'great',
#   'weekend',
#   'abiola'],
#  ['did',
#   'forget',
#   'to',
#   'tell',
#   'you',
#   'want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'now',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['who', 'are', 'you', 'seeing'],
#  ['great',
#   'hope',
#   'you',
#   'like',
#   'your',
#   'man',
#   'well',
#   'endowed',
#   'am',
#   'lt',
#   'gt',
#   'inch'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['didn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don',
#   'know',
#   'how',
#   'stubborn',
#   'am',
#   'didn',
#   'even',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'are',
#   'for',
#   'weak',
#   'sucker'],
#  ['what',
#   'you',
#   'thinked',
#   'about',
#   'me',
#   'first',
#   'time',
#   'you',
#   'saw',
#   'me',
#   'in',
#   'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations',
#   'thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave',
#   'sorry',
#   'didn',
#   'and',
#   'don',
#   'have',
#   'more',
#   'to',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'your',
#   'room',
#   'wa',
#   'so',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'or',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['do',
#   'you',
#   'know',
#   'what',
#   'mallika',
#   'sherawat',
#   'did',
#   'yesterday',
#   'find',
#   'out',
#   'now',
#   'lt',
#   'url',
#   'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'for',
#   'is',
#   'yours',
#   'call',
#   'now',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'all',
#   'free',
#   'bx',
#   'ip',
#   'we',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['sorry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['tell', 'where', 'you', 'reached'],
#  ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['your',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home',
#   'can',
#   'even',
#   'move',
#   'pain',
#   'is',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'are', 'situation', 'seeker'],
#  ['it', 'part', 'of', 'checking', 'iq'],
#  ['sorry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'he',
#   'said',
#   'will',
#   'cut',
#   'until',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no',
#   'you',
#   'are',
#   'awarded',
#   'with',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me',
#   'send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or',
#   'to',
#   'claim',
#   'txt',
#   'dis',
#   'to',
#   'morefrmmob',
#   'aj'],
#  ['did',
#   'you',
#   'hear',
#   'about',
#   'the',
#   'new',
#   'divorce',
#   'barbie',
#   'it',
#   'come',
#   'with',
#   'all',
#   'of',
#   'ken',
#   'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['finished', 'class', 'where', 'are', 'you'],
#  ['hi', 'babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something', 'xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free'],
#  ['thats',
#   'cool',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['doe', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['it',
#   'not',
#   'the',
#   'same',
#   'here',
#   'still',
#   'looking',
#   'for',
#   'job',
#   'how',
#   'much',
#   'do',
#   'ta',
#   'earn',
#   'there'],
#  ['sorry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network', 'if', 'urgnt', 'sm', 'me'],
#  ['for',
#   'real',
#   'when',
#   'getting',
#   'on',
#   'yo',
#   'only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done',
#   'already',
#   'used',
#   'all',
#   'my',
#   'multis'],
#  ['yes',
#   'started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed',
#   'double',
#   'coin',
#   'at',
#   'the',
#   'factory',
#   'too',
#   'gotta',
#   'cash',
#   'in',
#   'all',
#   'my',
#   'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['sorry',
#   'to',
#   'be',
#   'pain',
#   'is',
#   'it',
#   'ok',
#   'if',
#   'we',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that',
#   'sorry'],
#  ['smile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['havent',
#   'planning',
#   'to',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'only',
#   'got',
#   'show',
#   'in',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see',
#   'when',
#   'we',
#   'finish',
#   'we',
#   'have',
#   'load',
#   'of',
#   'loan',
#   'to',
#   'pay'],
#  ['hi',
#   'wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'doe',
#   'that',
#   'cause',
#   'prob',
#   'for'],
#  ['see', 'cup', 'of', 'coffee', 'animation'],
#  ['please',
#   'don',
#   'text',
#   'me',
#   'anymore',
#   'have',
#   'nothing',
#   'else',
#   'to',
#   'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'it',
#   'legal',
#   'wen',
#   'can',
#   'pick',
#   'them',
#   'up',
#   'ave',
#   'am',
#   'xx'],
#  ['still',
#   'looking',
#   'for',
#   'car',
#   'to',
#   'buy',
#   'and',
#   'have',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['wow',
#   'you',
#   're',
#   'right',
#   'didn',
#   'mean',
#   'to',
#   'do',
#   'that',
#   'guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'on',
#   'my',
#   'signin',
#   'page',
#   'it',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'for',
#   'your',
#   'wish',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['how',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'my',
#   'mom',
#   'wa',
#   'like',
#   'you',
#   'better',
#   'not',
#   'be',
#   'lying',
#   'then',
#   'again',
#   'am',
#   'always',
#   'the',
#   'one',
#   'to',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'he', 'busy'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['going', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok',
#   'wif',
#   'it',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'but',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'not',
#   'too',
#   'loud'],
#  ['gent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly',
#   'so',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'your',
#   'mobile',
#   'no',
#   'wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact',
#   'call',
#   'from',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['here',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apple',
#   'pair',
#   'all',
#   'that',
#   'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am',
#   'going',
#   'to',
#   'sao',
#   'mu',
#   'today',
#   'will',
#   'be',
#   'done',
#   'only',
#   'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['good', 'stuff', 'will', 'do'],
#  ['just',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet',
#   'just',
#   'sent',
#   'her',
#   'text',
#   'not',
#   'to',
#   'bother',
#   'sending',
#   'so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything',
#   'shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['hey',
#   'girl',
#   'how',
#   'hope',
#   'well',
#   'me',
#   'an',
#   'del',
#   'bak',
#   'again',
#   'long',
#   'time',
#   'no',
#   'give',
#   'me',
#   'call',
#   'sum',
#   'time',
#   'from',
#   'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'my', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in',
#   'txt',
#   'ansr',
#   'to',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to',
#   'nt',
#   'ec',
#   'msg'],
#  ['only', 'haf', 'msn', 'it', 'yijue', 'hotmail', 'com'],
#  ['he', 'is', 'there', 'you', 'call', 'and', 'meet', 'him'],
#  ['no', 'no', 'will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['got',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['sir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are', 'can', 'you', 'pls', 'open', 'the', 'back'],
#  ['yes', 'see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['whats', 'the', 'staff', 'name', 'who', 'is', 'taking', 'class', 'for'],
#  ['freemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['ummma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['sindu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['the', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['yup',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['you',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'window',
#   'even',
#   'on',
#   'my',
#   'shirt',
#   'and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too',
#   'time',
#   'of',
#   'joy',
#   'for',
#   'me',
#   'lot',
#   'of',
#   'tv',
#   'show',
#   'll',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aaooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['hello',
#   'my',
#   'love',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'did',
#   'you',
#   'get',
#   'to',
#   'that',
#   'interview',
#   'today',
#   'are',
#   'you',
#   'you',
#   'happy',
#   'are',
#   'you',
#   'being',
#   'good',
#   'boy',
#   'do',
#   'you',
#   'think',
#   'of',
#   'me',
#   'are',
#   'you',
#   'missing',
#   'me'],
#  ['customer',
#   'service',
#   'annoncement',
#   'you',
#   'have',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'for',
#   'you',
#   'please',
#   'call',
#   'now',
#   'to',
#   'arrange',
#   'delivery'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['new',
#   'car',
#   'and',
#   'house',
#   'for',
#   'my',
#   'parent',
#   'have',
#   'only',
#   'new',
#   'job',
#   'in',
#   'hand'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'is',
#   'on',
#   'the',
#   'way',
#   'should',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'if',
#   'do',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'on',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only'],
#  ['hi',
#   'frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['great',
#   'escape',
#   'fancy',
#   'the',
#   'bridge',
#   'but',
#   'need',
#   'her',
#   'lager',
#   'see',
#   'you',
#   'tomo'],
#  ['yes',
#   'it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['what', 'time', 'you', 'coming', 'down', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'you',
#   'forgot',
#   'my',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'it',
#   'spanish',
#   'and',
#   'begin',
#   'with'],
#  ['well',
#   'gonna',
#   'finish',
#   'my',
#   'bath',
#   'now',
#   'have',
#   'good',
#   'fine',
#   'night'],
#  ['let',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['turn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['text',
#   'her',
#   'if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['hi',
#   'you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'with',
#   'yes',
#   'or',
#   'no'],
#  ['you',
#   'lifted',
#   'my',
#   'hope',
#   'with',
#   'the',
#   'offer',
#   'of',
#   'money',
#   'am',
#   'in',
#   'need',
#   'especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying',
#   'anyways',
#   'have',
#   'gr',
#   'weekend'],
#  ['lol', 'no', 'can', 'trust', 'me'],
#  ['ok',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['he', 'will', 'you', 'guy', 'close'],
#  ['going', 'on', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'doe',
#   'he',
#   'miss',
#   'me'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['have',
#   'you',
#   'got',
#   'xmas',
#   'radio',
#   'time',
#   'if',
#   'not',
#   'will',
#   'get',
#   'it',
#   'now'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'my',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'when',
#   'she',
#   'finish'],
#  ['are',
#   'you',
#   'unique',
#   'enough',
#   'find',
#   'out',
#   'from',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   've',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch',
#   'you',
#   'mean',
#   'great',
#   'deal',
#   'to',
#   'me',
#   'you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost',
#   'do',
#   'have',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'the', 'course'],
#  ['it',
#   'will',
#   'stop',
#   'on',
#   'itself',
#   'however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['how',
#   'are',
#   'you',
#   'doing',
#   'hope',
#   'you',
#   've',
#   'settled',
#   'in',
#   'for',
#   'the',
#   'new',
#   'school',
#   'year',
#   'just',
#   'wishin',
#   'you',
#   'gr',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['did', 'got', 'that', 'person', 'story'],
#  ['is',
#   'your',
#   'hamster',
#   'dead',
#   'hey',
#   'so',
#   'tmr',
#   'meet',
#   'you',
#   'at',
#   'pm',
#   'orchard',
#   'mrt'],
#  ['hi',
#   'it',
#   'kate',
#   'how',
#   'is',
#   'your',
#   'evening',
#   'hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'if',
#   'can',
#   'xxx'],
#  ['found', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['your',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'transaction',
#   'id',
#   'is',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['you',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['both', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['what',
#   'up',
#   'bruv',
#   'hope',
#   'you',
#   'had',
#   'great',
#   'break',
#   'do',
#   'have',
#   'rewarding',
#   'semester'],
#  ['home', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'how', 'noe', 'leh'],
#  ['sound', 'great', 'are', 'you', 'home', 'now'],
#  ['finally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['tired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['yeah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['ok', 'no', 'prob', 'take', 'ur', 'time'],
#  ['there',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['sorry', 'll', 'call', 'later'],
#  ['say',
#   'leh',
#   'of',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'only',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'not',
#   'so',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'from',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would',
#   'really',
#   'appreciate',
#   'if',
#   'you',
#   'call',
#   'me',
#   'just',
#   'need',
#   'someone',
#   'to',
#   'talk',
#   'to'],
#  ['will',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'is',
#   'ur',
#   'career',
#   'off',
#   'flyng',
#   'start',
#   'find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['get',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'here'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['have', 'printed', 'it', 'oh', 'so', 'lt', 'gt', 'come', 'upstairs'],
#  ['or',
#   'ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['where', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person',
#   'so',
#   'dont',
#   'argue',
#   'with',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'them',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['okay',
#   'no',
#   'no',
#   'just',
#   'shining',
#   'on',
#   'that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['too',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['kallis', 'wont', 'bat', 'in', 'nd', 'inning'],
#  ['it',
#   'didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'have',
#   'nice',
#   'day',
#   'da'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['ups',
#   'which',
#   'is',
#   'day',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks',
#   'the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['don',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['where', 'are', 'you', 'lover', 'need', 'you'],
#  ['we',
#   'tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'or',
#   'call',
#   'now'],
#  ['parked',
#   'next',
#   'to',
#   'mini',
#   'when',
#   'are',
#   'you',
#   'coming',
#   'in',
#   'today',
#   'do',
#   'you',
#   'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'on',
#   'my',
#   'own',
#   'now',
#   'co',
#   'my',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['my', 'no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['hey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['why', 'you', 'dint', 'come', 'with'],
#  ['same', 'wana', 'plan', 'trip', 'sometme', 'then'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ur',
#   'ringtone',
#   'service',
#   'ha',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'to',
#   'club',
#   'mobile',
#   'com',
#   'to',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'to',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['the', 'evo', 'just', 'had', 'to', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone',
#   'this',
#   'message',
#   'is',
#   'free',
#   'of',
#   'charge'],
#  ['come',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['night',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way',
#   'may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection', 'my', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['awesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['just',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['all',
#   'done',
#   'all',
#   'handed',
#   'in',
#   'celebration',
#   'in',
#   'full',
#   'swing',
#   'yet'],
#  ['you', 'got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'the',
#   'person',
#   'is',
#   'definitely',
#   'special',
#   'for',
#   'but',
#   'if',
#   'the',
#   'person',
#   'is',
#   'so',
#   'special',
#   'why',
#   'to',
#   'miss',
#   'them',
#   'just',
#   'keep',
#   'in',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'for', 'money', 'how', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'with',
#   'my',
#   'girl',
#   'friend',
#   'what',
#   'up',
#   'give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['my',
#   'life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friend',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'thing',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['hey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['haf', 'found', 'him', 'feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['oops', 'got', 'that', 'bit'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'on',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['need',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['awesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['shit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second',
#   'def',
#   'up',
#   'for',
#   'night',
#   'out',
#   'do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['oh',
#   'and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge',
#   'want',
#   'to',
#   'go',
#   'out',
#   'for',
#   'meal',
#   'tonight'],
#  ['he', 'is', 'womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'is',
#   'from',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'him',
#   'out',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['jos', 'ask', 'if', 'wana', 'meet', 'up'],
#  ['lol',
#   'yes',
#   'our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['where',
#   'are',
#   'the',
#   'garage',
#   'key',
#   'they',
#   'aren',
#   'on',
#   'the',
#   'bookshelf'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['he',
#   'say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['hi',
#   'the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'the',
#   'rest',
#   'of',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'wa',
#   'lost'],
#  ['you', 'made', 'my', 'day', 'do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['december',
#   'only',
#   'had',
#   'your',
#   'mobile',
#   'mths',
#   'you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kiss'],
#  ['hey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['that',
#   'would',
#   'be',
#   'great',
#   'we',
#   'll',
#   'be',
#   'at',
#   'the',
#   'guild',
#   'could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend',
#   'our',
#   'plan',
#   'take',
#   'flight',
#   'have',
#   'good',
#   'week'],
#  ['no', 'problem', 'how', 'are', 'you', 'doing'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading',
#   'the',
#   'text',
#   'just',
#   'sent',
#   'you',
#   'it',
#   'meant',
#   'to',
#   'be',
#   'joke',
#   'so',
#   'read',
#   'it',
#   'in',
#   'that',
#   'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['call',
#   'germany',
#   'for',
#   'only',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['any',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'at',
#   'all',
#   'please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['cool',
#   'so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
# ...
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like',
#   'to',
#   'talk',
#   'pa',
#   'but',
#   'am',
#   'not',
#   'able',
#   'to',
#   'dont',
#   'know'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['you', 'unbelievable', 'faglord'],
#  ['wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['why', 'do', 'you', 'ask', 'princess'],
#  ['am', 'great', 'princess', 'what', 'are', 'you', 'thinking', 'about', 'me'],
#  ['nutter',
#   'cutter',
#   'ctter',
#   'cttergg',
#   'cttargg',
#   'ctargg',
#   'ctagg',
#   'ie',
#   'you'],
#  ['it',
#   'ok',
#   'noe',
#   're',
#   'busy',
#   'but',
#   'really',
#   'too',
#   'bored',
#   'so',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'she',
#   'choose',
#   'me',
#   'one'],
#  ['doesn',
#   'have',
#   'class',
#   'early',
#   'tomorrow',
#   'and',
#   'thus',
#   'shouldn',
#   'be',
#   'trying',
#   'to',
#   'smoke',
#   'at',
#   'lt',
#   'gt'],
#  ['superb',
#   'thought',
#   'be',
#   'grateful',
#   'that',
#   'dont',
#   'have',
#   'everything',
#   'want',
#   'that',
#   'mean',
#   'still',
#   'have',
#   'an',
#   'opportunity',
#   'to',
#   'be',
#   'happier',
#   'tomorrow',
#   'than',
#   'are',
#   'today'],
#  ['hope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['used',
#   'to',
#   'it',
#   'just',
#   'hope',
#   'my',
#   'agent',
#   'don',
#   'drop',
#   'me',
#   'since',
#   've',
#   'only',
#   'booked',
#   'few',
#   'thing',
#   'this',
#   'year',
#   'this',
#   'whole',
#   'me',
#   'in',
#   'boston',
#   'them',
#   'in',
#   'nyc',
#   'wa',
#   'an',
#   'experiment'],
#  ['thursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'are',
#   'coming',
#   'due',
#   'and',
#   'have',
#   'several',
#   'outstanding',
#   'invoice',
#   'for',
#   'work',
#   'did',
#   'two',
#   'and',
#   'three',
#   'month',
#   'ago'],
#  ['how', 'is', 'it', 'possible', 'to', 'teach', 'you', 'and', 'where'],
#  ['wonder',
#   'if',
#   'your',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   'had',
#   'to',
#   'tell',
#   'you',
#   'love',
#   'you',
#   'babe'],
#  ['lovely', 'smell', 'on', 'this', 'bus', 'and', 'it', 'ain', 'tobacco'],
#  ['we',
#   're',
#   'all',
#   'getting',
#   'worried',
#   'over',
#   'here',
#   'derek',
#   'and',
#   'taylor',
#   'have',
#   'already',
#   'assumed',
#   'the',
#   'worst'],
#  ['hey', 'what', 'up', 'charles', 'sorry', 'about', 'the', 'late', 'reply'],
#  ['all',
#   'the',
#   'lastest',
#   'from',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'and',
#   'the',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'with',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'or',
#   'text',
#   'wap',
#   'to'],
#  ['ll',
#   'give',
#   'her',
#   'once',
#   'have',
#   'it',
#   'plus',
#   'she',
#   'said',
#   'grinule',
#   'greet',
#   'you',
#   'whenever',
#   'we',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'are', 'in', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'now',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'from',
#   'min',
#   'cheap',
#   'to',
#   'min',
#   'peak',
#   'to',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['my',
#   'love',
#   'how',
#   'come',
#   'it',
#   'took',
#   'you',
#   'so',
#   'long',
#   'to',
#   'leave',
#   'for',
#   'zaher',
#   'got',
#   'your',
#   'word',
#   'on',
#   'ym',
#   'and',
#   'wa',
#   'happy',
#   'to',
#   'see',
#   'them',
#   'but',
#   'wa',
#   'sad',
#   'you',
#   'had',
#   'left',
#   'miss',
#   'you'],
#  ['am', 'sorry', 'it', 'hurt', 'you'],
#  ['can',
#   'feel',
#   'nauseous',
#   'so',
#   'pissed',
#   'didn',
#   'eat',
#   'any',
#   'sweet',
#   'all',
#   'week',
#   'cause',
#   'today',
#   'wa',
#   'planning',
#   'to',
#   'pig',
#   'out',
#   'wa',
#   'dieting',
#   'all',
#   'week',
#   'and',
#   'now',
#   'not',
#   'hungry'],
#  ['ok',
#   'lor',
#   'but',
#   'not',
#   'too',
#   'early',
#   'me',
#   'still',
#   'having',
#   'project',
#   'meeting',
#   'now'],
#  ['call', 'me', 'da', 'am', 'waiting', 'for', 'your', 'call'],
#  ['could',
#   'ask',
#   'carlos',
#   'if',
#   'we',
#   'could',
#   'get',
#   'more',
#   'if',
#   'anybody',
#   'else',
#   'can',
#   'chip',
#   'in'],
#  ['wa',
#   'actually',
#   'about',
#   'to',
#   'send',
#   'you',
#   'reminder',
#   'today',
#   'have',
#   'wonderful',
#   'weekend'],
#  ['when',
#   'people',
#   'see',
#   'my',
#   'msg',
#   'they',
#   'think',
#   'iam',
#   'addicted',
#   'to',
#   'msging',
#   'they',
#   'are',
#   'wrong',
#   'bcoz',
#   'they',
#   'don',
#   'know',
#   'that',
#   'iam',
#   'addicted',
#   'to',
#   'my',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'you',
#   'gave',
#   'them',
#   'your',
#   'photo',
#   'when',
#   'you',
#   'registered',
#   'for',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'at',
#   'yck'],
#  ['dont', 'talk', 'to', 'him', 'ever', 'ok', 'it', 'my', 'word'],
#  ['when', 'wana', 'see', 'it', 'then'],
#  ['on',
#   'ma',
#   'way',
#   'to',
#   'school',
#   'can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'ashley',
#   'number'],
#  ['it', 'shall', 'be', 'fine', 'have', 'avalarr', 'now', 'will', 'hollalater'],
#  ['she',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'my',
#   'old',
#   'website',
#   'now',
#   'blogging',
#   'at',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['but',
#   'on',
#   'diet',
#   'and',
#   'ate',
#   'too',
#   'many',
#   'slice',
#   'of',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'on',
#   'diet'],
#  ['will', 'give', 'my', 'kvb', 'acc', 'detail'],
#  ['oh', 'all', 'have', 'to', 'come', 'ah'],
#  ['money',
#   'you',
#   'lucky',
#   'winner',
#   'claim',
#   'your',
#   'prize',
#   'text',
#   'money',
#   'over',
#   'million',
#   'to',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'won',
#   'able',
#   'do',
#   'this',
#   'friday',
#   'hope',
#   'can',
#   'find',
#   'an',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   're',
#   'wa',
#   'enjoy',
#   'it',
#   'and',
#   'wish',
#   'you',
#   'many',
#   'happy',
#   'moment',
#   'to',
#   'and',
#   'fro',
#   'wherever',
#   'you',
#   'go'],
#  ['so', 'do', 'you', 'have', 'samus', 'shoulder', 'yet'],
#  ['what',
#   'time',
#   'you',
#   'think',
#   'you',
#   'll',
#   'have',
#   'it',
#   'need',
#   'to',
#   'know',
#   'when',
#   'should',
#   'be',
#   'near',
#   'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['then', 'dun', 'wear', 'jean', 'lor'],
#  ['since', 'when', 'which', 'side', 'any', 'fever', 'any', 'vomitin'],
#  ['are', 'you', 'in', 'college'],
#  ['urgent',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'up',
#   'for',
#   'friday',
#   'and',
#   'stuffed',
#   'myself',
#   'like',
#   'pig',
#   'yesterday',
#   'now',
#   'feel',
#   'bleh',
#   'but',
#   'at',
#   'least',
#   'it',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'of',
#   'bleh'],
#  ['no',
#   'we',
#   'sell',
#   'it',
#   'all',
#   'so',
#   'we',
#   'll',
#   'have',
#   'ton',
#   'if',
#   'coin',
#   'then',
#   'sell',
#   'our',
#   'coin',
#   'to',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'in',
#   'life',
#   'pocket'],
#  ['theyre',
#   'doing',
#   'it',
#   'to',
#   'lot',
#   'of',
#   'place',
#   'only',
#   'hospital',
#   'and',
#   'medical',
#   'place',
#   'are',
#   'safe'],
#  ['how',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folk',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sm'],
#  ['and',
#   'also',
#   've',
#   'sorta',
#   'blown',
#   'him',
#   'off',
#   'couple',
#   'time',
#   'recently',
#   'so',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'him',
#   'out',
#   'of',
#   'the',
#   'blue',
#   'looking',
#   'for',
#   'weed'],
#  ['sent',
#   'my',
#   'score',
#   'to',
#   'sophas',
#   'and',
#   'had',
#   'to',
#   'do',
#   'secondary',
#   'application',
#   'for',
#   'few',
#   'school',
#   'think',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'of',
#   'applying',
#   'do',
#   'research',
#   'on',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'her',
#   'school',
#   'is',
#   'one',
#   'me',
#   'the',
#   'le',
#   'expensive',
#   'one'],
#  ['cant',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'how',
#   'were',
#   'the',
#   'photo',
#   'were',
#   'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   'pound',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'the',
#   'kb',
#   'on',
#   'sat',
#   'already',
#   'what',
#   'other',
#   'lesson',
#   'are',
#   'we',
#   'going',
#   'for',
#   'ah',
#   'keep',
#   'your',
#   'sat',
#   'night',
#   'free',
#   'we',
#   'need',
#   'to',
#   'meet',
#   'and',
#   'confirm',
#   'our',
#   'lodging'],
#  ['chk', 'in', 'ur', 'belovd', 'dict'],
#  ['is', 'that', 'what', 'time', 'you', 'want', 'me', 'to', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'you', 're', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'against',
#   'gravity',
#   'read',
#   'carefully',
#   'our',
#   'heart',
#   'feel',
#   'light',
#   'when',
#   'someone',
#   'is',
#   'in',
#   'it',
#   'but',
#   'it',
#   'feel',
#   'very',
#   'heavy',
#   'when',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['also', 'remember', 'to', 'get', 'dobby', 'bowl', 'from', 'your', 'car'],
#  ['filthy', 'story', 'and', 'girl', 'waiting', 'for', 'your'],
#  ['sorry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['love',
#   'isn',
#   'decision',
#   'it',
#   'feeling',
#   'if',
#   'we',
#   'could',
#   'decide',
#   'who',
#   'to',
#   'love',
#   'then',
#   'life',
#   'would',
#   'be',
#   'much',
#   'simpler',
#   'but',
#   'then',
#   'le',
#   'magical'],
#  ['welp', 'apparently', 'he', 'retired'],
#  ['my',
#   'sort',
#   'code',
#   'is',
#   'and',
#   'acc',
#   'no',
#   'is',
#   'the',
#   'bank',
#   'is',
#   'natwest',
#   'can',
#   'you',
#   'reply',
#   'to',
#   'confirm',
#   've',
#   'sent',
#   'this',
#   'to',
#   'the',
#   'right',
#   'person'],
#  ['where'],
#  ['sure', 'can', 'take', 'any', 'sick', 'time'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr',
#   'only'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['yo',
#   'chad',
#   'which',
#   'gymnastics',
#   'class',
#   'do',
#   'you',
#   'wanna',
#   'take',
#   'the',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'is',
#   'full'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['or',
#   'better',
#   'still',
#   'can',
#   'you',
#   'catch',
#   'her',
#   'and',
#   'let',
#   'ask',
#   'her',
#   'if',
#   'she',
#   'can',
#   'sell',
#   'lt',
#   'gt',
#   'for',
#   'me'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['what',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['are', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class'],
#  ['it', 'wont', 'until', 'trying', 'sort', 'house', 'out', 'is', 'that', 'ok'],
#  ['yar',
#   'lor',
#   'he',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'so',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back', 'now', 'then'],
#  ['yup', 'thk', 'so', 'until', 'shop', 'close', 'lor'],
#  ['what', 'is', 'your', 'account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'wa',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'with',
#   'me',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk', 'to', 'him'],
#  ['dont',
#   'hesitate',
#   'you',
#   'know',
#   'this',
#   'is',
#   'the',
#   'second',
#   'time',
#   'she',
#   'ha',
#   'had',
#   'weakness',
#   'like',
#   'that',
#   'so',
#   'keep',
#   'notebook',
#   'of',
#   'what',
#   'she',
#   'eat',
#   'and',
#   'did',
#   'the',
#   'day',
#   'before',
#   'or',
#   'if',
#   'anything',
#   'changed',
#   'the',
#   'day',
#   'before',
#   'so',
#   'that',
#   'we',
#   'can',
#   'be',
#   'sure',
#   'it',
#   'nothing'],
#  ['hey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'and', 'alcohol'],
#  ['if',
#   'he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'day',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['reckon',
#   'need',
#   'to',
#   'be',
#   'in',
#   'town',
#   'by',
#   'eightish',
#   'to',
#   'walk',
#   'from',
#   'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'your',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look',
#   'at',
#   'the',
#   'fuckin',
#   'time',
#   'what',
#   'the',
#   'fuck',
#   'you',
#   'think',
#   'is',
#   'up'],
#  ['yo', 'guess', 'what', 'just', 'dropped'],
#  ['carlos', 'say', 'he', 'll', 'be', 'at', 'mu', 'in', 'lt', 'gt', 'minute'],
#  ['in', 'office', 'now', 'will', 'call', 'you', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'you',
#   'already',
#   'you',
#   'know',
#   'your',
#   'all',
#   'can',
#   'think',
#   'about',
#   'fuck',
#   'can',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'when',
#   'we',
#   'will',
#   'be',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'the',
#   'ubi',
#   'one',
#   'say',
#   'if',
#   'wan',
#   'call',
#   'by',
#   'tomorrow',
#   'call',
#   'look',
#   'for',
#   'irene',
#   'ere',
#   'only',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'for',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh',
#   'gotta',
#   'drive',
#   'back',
#   'to',
#   'sd',
#   'from',
#   'la',
#   'my',
#   'butt',
#   'is',
#   'sore'],
#  ['th', 'of', 'july'],
#  ['hi',
#   'im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'wa',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['up',
#   'to',
#   'wan',
#   'come',
#   'then',
#   'come',
#   'lor',
#   'but',
#   'din',
#   'any',
#   'stripe',
#   'skirt'],
#  ['the',
#   'xmas',
#   'story',
#   'is',
#   'peace',
#   'the',
#   'xmas',
#   'msg',
#   'is',
#   'love',
#   'the',
#   'xmas',
#   'miracle',
#   'is',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['can', 'don', 'have', 'her', 'number'],
#  ['change', 'again', 'it', 'one', 'next', 'to', 'escalator'],
#  ['yetunde',
#   'in',
#   'class',
#   'can',
#   'you',
#   'not',
#   'run',
#   'water',
#   'on',
#   'it',
#   'to',
#   'make',
#   'it',
#   'ok',
#   'pls',
#   'now'],
#  ['not',
#   'lot',
#   'ha',
#   'happened',
#   'here',
#   'feel',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunt',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lot',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['then',
#   'wait',
#   'me',
#   'at',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'if',
#   'dun',
#   'then',
#   'go',
#   'get',
#   'my',
#   'car',
#   'then',
#   'come',
#   'back',
#   'pick'],
#  ...]

# %%
import gensim

# %%
## Lets train Word2vec from scratch
model=gensim.models.Word2Vec(words)

# %%
## To Get All the Vocabulary
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
#  'any',
#  'her',
#  'ha',
#  'co',
#  'did',
#  'been',
#  'msg',
#  'min',
#  'some',
#  'an',
#  'night',
#  'make',
#  'dear',
#  'who',
#  'here',
#  'message',
#  'say',
#  'well',
#  'where',
#  're',
#  'thing',
#  'much',
#  'oh',
#  'great',
#  'claim',
#  'hope',
#  'hey',
#  'him',
#  'number',
#  'give',
#  'more',
#  'too',
#  'happy',
#  'work',
#  'wat',
#  'friend',
#  'had',
#  'yes',
#  'way',
#  'www',
#  've',
#  'let',
#  'should',
#  'prize',
#  'won',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'after',
#  'ask',
#  'win',
#  'said',
#  'life',
#  'amp',
#  'cash',
#  'doing',
#  'im',
#  'yeah',
#  'really',
#  'meet',
#  'babe',
#  'why',
#  'find',
#  'them',
#  'miss',
#  'morning',
#  'very',
#  'last',
#  'year',
#  'service',
#  'thanks',
#  'uk',
#  'care',
#  'com',
#  'would',
#  'anything',
#  'lol',
#  'nokia',
#  'also',
#  'every',
#  'feel',
#  'keep',
#  'sure',
#  'pick',
#  'urgent',
#  'over',
#  'sent',
#  'contact',
#  'something',
#  'buy',
#  'gud',
#  'again',
#  'cant',
#  'wait',
#  'before',
#  'place',
#  'box',
#  'first',
#  'his',
#  'even',
#  'someone',
#  'guy',
#  'help',
#  'went',
#  'wish',
#  'next',
#  'tonight',
#  'were',
#  'nice',
#  'soon',
#  'show',
#  'which',
#  'off',
#  'around',
#  'word',
#  'could',
#  'customer',
#  'money',
#  'sleep',
#  'chat',
#  'per',
#  'many',
#  'late',
#  'always',
#  'ya',
#  'gonna',
#  'sm',
#  'down',
#  'leave',
#  'wan',
#  'name',
#  'lot',
#  'end',
#  'other',
#  'dun',
#  'pm',
#  'told',
#  'st',
#  'person',
#  'waiting',
#  'hello',
#  'special',
#  'try',
#  'month',
#  'girl',
#  'hour',
#  'may',
#  'fine',
#  'best',
#  'haha',
#  'minute',
#  'heart',
#  'people',
#  'coming',
#  'done',
#  'guaranteed',
#  'yet',
#  'thk',
#  'same',
#  'th',
#  'getting',
#  'smile',
#  'ppm',
#  'use',
#  'thought',
#  'god',
#  'didn',
#  'offer',
#  'stuff',
#  'holiday',
#  'talk',
#  'start',
#  'class',
#  'man',
#  'cost',
#  'live',
#  'mean',
#  'bit',
#  'line',
#  'car',
#  'lunch',
#  'few',
#  'draw',
#  'finish',
#  'job',
#  'being',
#  'problem',
#  'never',
#  'yup',
#  'ill',
#  'better',
#  'plan',
#  'trying',
#  'house',
#  'thats',
#  'cool',
#  'hr',
#  'meeting',
#  'account',
#  'rate',
#  'mind',
#  'pobox',
#  'ready',
#  'having',
#  'dat',
#  'long',
#  'weekend',
#  'game',
#  'chance',
#  'world',
#  'real',
#  'half',
#  'enjoy',
#  'latest',
#  'wk',
#  'po',
#  'room',
#  'yo',
#  'sir',
#  'check',
#  'because',
#  'than',
#  'bt',
#  'guess',
#  'play',
#  'awarded',
#  'wanna',
#  'nothing',
#  'lar',
#  'receive',
#  'boy',
#  'voucher',
#  'eat',
#  'sweet',
#  'luv',
#  'look',
#  'camera',
#  'pic',
#  'another',
#  'liao',
#  'big',
#  'shit',
#  'dinner',
#  'into',
#  'ah',
#  'landline',
#  'birthday',
#  'xxx',
#  'jus',
#  'might',
#  'ever',
#  'quite',
#  'video',
#  'kiss',
#  'age',
#  'watching',
#  'wont',
#  'question',
#  'land',
#  'watch',
#  'dream',
#  'orange',
#  'early',
#  'thanx',
#  'worry',
#  'baby',
#  'called',
#  'speak',
#  'two',
#  'tv',
#  'aight',
#  'once',
#  'hear',
#  'fun',
#  'probably',
#  'nd',
#  'point',
#  'bed',
#  'pa',
#  'pay',
#  'doe',
#  'actually',
#  'network',
#  'princess',
#  'nite',
#  'apply',
#  'maybe',
#  'shall',
#  'bus',
#  'part',
#  'sat',
#  'left',
#  'forgot',
#  'den',
#  'bad',
#  'ringtone',
#  'remember',
#  'office',
#  'hurt',
#  'easy',
#  'reach',
#  'code',
#  'shopping',
#  'between',
#  'dunno',
#  'made',
#  'xx',
#  'dis',
#  'little',
#  'evening',
#  'didnt',
#  'award',
#  'put',
#  'true',
#  'leh',
#  'fuck',
#  'everything',
#  'wife',
#  'anyway',
#  'face',
#  'dad',
#  'looking',
#  'town',
#  'thank',
#  'afternoon',
#  'gift',
#  'school',
#  'enough',
#  'sound',
#  'those',
#  'mail',
#  'working',
#  'mate',
#  'selected',
#  'yr',
#  'movie',
#  'most',
#  'collect',
#  'pound',
#  'detail',
#  'without',
#  'asked',
#  'entry',
#  'while',
#  'missing',
#  'tmr',
#  'hav',
#  'join',
#  'price',
#  'sexy',
#  'okay',
#  'though',
#  'pain',
#  'wif',
#  'important',
#  'must',
#  'xmas',
#  'wanted',
#  'until',
#  'since',
#  'valid',
#  'came',
#  'update',
#  'mob',
#  'answer',
#  'wot',
#  'lesson',
#  'missed',
#  'wake',
#  'book',
#  'abt',
#  'run',
#  'collection',
#  'bring',
#  'able',
#  'til',
#  'wen',
#  'haven',
#  'decimal',
#  'de',
#  'test',
#  'charge',
#  'juz',
#  'plus',
#  'change',
#  'stay',
#  'date',
#  'plz',
#  'colour',
#  'away',
#  'double',
#  'weekly',
#  'havent',
#  'yesterday',
#  'saw',
#  'else',
#  'music',
#  'till',
#  'shop',
#  'dude',
#  'bored',
#  'attempt',
#  'alright',
#  'hair',
#  'lei',
#  'food',
#  'optout',
#  'trip',
#  'credit',
#  'friendship',
#  'making',
#  'drink',
#  'net',
#  'these',
#  'online',
#  'id',
#  'haf',
#  'yours',
#  'top',
#  'oso',
#  'coz',
#  'goin',
#  'tried',
#  'gr',
#  'family',
#  'address',
#  'delivery',
#  'sch',
#  'hot',
#  'player',
#  'club',
#  'either',
#  'smoke',
#  'ard',
#  'driving',
#  'feeling',
#  'national',
#  'yourself',
#  'nt',
#  'sad',
#  'order',
#  'lose',
#  'together',
#  'calling',
#  'full',
#  'wid',
#  'second',
#  'story',
#  'mom',
#  'busy',
#  'ring',
#  'beautiful',
#  'head',
#  'bonus',
#  'walk',
#  'http',
#  'brother',
#  'tot',
#  'both',
#  'si',
#  'sae',
#  'post',
#  'believe',
#  'smiling',
#  'huh',
#  'close',
#  'poly',
#  'old',
#  'eve',
#  'row',
#  'chikku',
#  'happen',
#  'noe',
#  'drive',
#  'await',
#  'set',
#  'info',
#  'hand',
#  'saying',
#  'mum',
#  'sleeping',
#  'leaving',
#  'awesome',
#  'mths',
#  'took',
#  'congrats',
#  'pub',
#  'hl',
#  'email',
#  'drop',
#  'parent',
#  'wil',
#  'rite',
#  'tomo',
#  'match',
#  'thinking',
#  'suite',
#  'started',
#  'news',
#  'simple',
#  'aft',
#  'finished',
#  'private',
#  'cause',
#  'doesn',
#  'okie',
#  'tho',
#  'unsubscribe',
#  'auction',
#  'available',
#  'tc',
#  'forget',
#  'content',
#  'everyone',
#  'company',
#  'anyone',
#  'sister',
#  'touch',
#  'break',
#  'caller',
#  'valentine',
#  'reason',
#  'mine',
#  'final',
#  'card',
#  'angry',
#  'neva',
#  'taking',
#  'gd',
#  'statement',
#  'open',
#  'dating',
#  'loving',
#  'whats',
#  'alone',
#  'found',
#  'treat',
#  'whatever',
#  'lucky',
#  'fancy',
#  'carlos',
#  'gal',
#  'choose',
#  'worth',
#  'opt',
#  'each',
#  'ticket',
#  'search',
#  'sun',
#  'knw',
#  'type',
#  'bank',
#  'expires',
#  'wonderful',
#  'frnd',
#  'hows',
#  'mobileupd',
#  'hit',
#  'winner',
#  'hard',
#  'boytoy',
#  'gone',
#  'saturday',
#  'gbp',
#  'welcome',
#  'fast',
#  'happened',
#  'quiz',
#  'anytime',
#  'kind',
#  'congratulation',
#  'bout',
#  'secret',
#  'far',
#  'identifier',
#  'decided',
#  'sub',
#  'ni',
#  'exam',
#  'uncle',
#  'ltd',
#  'party',
#  'smth',
#  'friday',
#  'college',
#  'visit',
#  'nyt',
#  'prob',
#  'song',
#  'darlin',
#  'mu',
#  'hold',
#  'read',
#  'light',
#  'operator',
#  'oredi',
#  'goodmorning',
#  'finally',
#  'mrng',
#  'tel',
#  'sea',
#  'wit',
#  'used',
#  'camcorder',
#  'wrong',
#  'least',
#  'wonder',
#  'fucking',
#  'drug',
#  'chennai',
#  'project',
#  'lovely',
#  'crazy',
#  'fri',
#  'term',
#  'nope',
#  'outside',
#  'pretty',
#  'fone',
#  'meant',
#  'frm',
#  'hmm',
#  'seeing',
#  'savamob',
#  'telling',
#  'case',
#  'fr',
#  'ten',
#  'whole',
#  'cum',
#  'cd',
#  'their',
#  'unlimited',
#  'blue',
#  'frnds',
#  'listen',
#  'snow',
#  'le',
#  'freemsg',
#  'support',
#  'wkly',
#  'wq',
#  'earlier',
#  'isn',
#  'course',
#  'hungry',
#  'jay',
#  'wasn',
#  'sunday',
#  'log',
#  'john',
#  'understand',
#  'enter',
#  'eh',
#  'single',
#  'cut',
#  'gas',
#  'un',
#  'father',
#  'valued',
#  'within',
#  'stupid',
#  'press',
#  'mr',
#  'hee',
#  'die',
#  'hmmm',
#  'yar',
#  'happiness',
#  'move',
#  'almost',
#  'knew',
#  'child',
#  'store',
#  'tired',
#  'bslvyl',
#  'mayb',
#  'sell',
#  'gn',
#  'balance',
#  'na',
#  'dnt',
#  'film',
#  'sex',
#  'paper',
#  'luck',
#  'joy',
#  'pas',
#  'moment',
#  'etc',
#  'march',
#  'side',
#  'area',
#  'sk',
#  'currently',
#  'couple',
#  'txts',
#  'computer',
#  'rock',
#  'invited',
#  'felt',
#  'as',
#  'ago',
#  'download',
#  'india',
#  'talking',
#  'mah',
#  'christmas',
#  'lost',
#  'park',
#  'motorola',
#  'load',
#  'reading',
#  'shower',
#  'hospital',
#  'bill',
#  'picking',
#  'askd',
#  'ipod',
#  'darren',
#  'eye',
#  'direct',
#  'return',
#  'heard',
#  'rental',
#  'photo',
#  'extra',
#  'confirm',
#  'semester',
#  'correct',
#  'via',
#  'red',
#  'doin',
#  'ac',
#  'information',
#  'supposed',
#  'reveal',
#  'wow',
#  'sort',
#  'laptop',
#  'ugh',
#  'charged',
#  'xy',
#  'bcoz',
#  'sending',
#  'ish',
#  'swing',
#  'seen',
#  'redeemed',
#  'difficult',
#  'ge',
#  'through',
#  'promise',
#  'met',
#  'max',
#  'lady',
#  'gym',
#  'complimentary',
#  'kid',
#  'gotta',
#  'comp',
#  'grin',
#  'surprise',
#  'figure',
#  'police',
#  'whenever',
#  'discount',
#  'slowly',
#  'ex',
#  'yep',
#  'muz',
#  'lovable',
#  'request',
#  'bath',
#  'hg',
#  'std',
#  'abiola',
#  'crave',
#  'usf',
#  'eg',
#  'loan',
#  'reward',
#  'safe',
#  'small',
#  'road',
#  'wine',
#  'comin',
#  'slow',
#  'weed',
#  'nobody',
#  'truth',
#  'link',
#  'wap',
#  'study',
#  'fantasy',
#  'fact',
#  'loved',
#  'orchard',
#  'cheer',
#  'asap',
#  'kate',
#  'somebody',
#  'page',
#  'noon',
#  'remove',
#  'rply',
#  'hmv',
#  'leaf',
#  'entered',
#  'txting',
#  'blood',
#  'rest',
#  'wana',
#  'idea',
#  'clean',
#  'dogging',
#  'door',
#  'asking',
#  'checking',
#  'train',
#  'own',
#  'lover',
#  'laugh',
#  'joke',
#  'save',
#  'rent',
#  'member',
#  'monday',
#  'pete',
#  'copy',
#  'empty',
#  'deal',
#  'nah',
#  'near',
#  'del',
#  'forever',
#  'mistake',
#  'energy',
#  'cup',
#  'normal',
#  'somewhere',
#  'men',
#  'england',
#  'la',
#  'situation',
#  'opinion',
#  'cheap',
#  'warm',
#  'hoping',
#  'water',
#  'across',
#  'woke',
#  'hw',
#  'usual',
#  'rakhesh',
#  'callertune',
#  'spend',
#  'med',
#  'em',
#  'cover',
#  'write',
#  'short',
#  'gave',
#  'bb',
#  'ringtones',
#  'tonite',
#  'bathe',
#  'different',
#  'voice',
#  'teach',
#  'ho',
#  'otherwise',
#  'king',
#  'merry',
#  'gap',
#  'poor',
#  'fantastic',
#  'booked',
#  'oops',
#  'wc',
#  'gettin',
#  'bag',
#  'admirer',
#  'getzed',
#  'ldn',
#  'kick',
#  'glad',
#  'immediately',
#  'street',
#  'summer',
#  'wishing',
#  'representative',
#  'cr',
#  'ntt',
#  'sony',
#  'rd',
#  'deep',
#  'worried',
#  'turn',
#  'catch',
#  'reached',
#  'pray',
#  ...]

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('all', 0.9984238147735596),
#  ('dear', 0.998331606388092),
#  ('day', 0.998270571231842),
#  ('wa', 0.9982663989067078),
#  ('morning', 0.9982471466064453),
#  ('hope', 0.9982280135154724),
#  ('night', 0.9982033371925354),
#  ('not', 0.9981970191001892),
#  ('well', 0.9981840252876282),
#  ('where', 0.9981786608695984)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat']

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages (4.66.5)

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|          | 0/5569 [00:00<?, ?it/s]/Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/cybesama/Desktop/tryout/venv/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5569/5569 [00:00<00:00, 12323.04it/s]

# %%
len(X)
# Out:
# 5569

# %%
X
# Out:
# [array([-0.22453453,  0.21703535,  0.11557314,  0.11826   ,  0.07060363,
#         -0.47909608,  0.13316263,  0.4723991 , -0.23117144, -0.13247146,
#         -0.17043072, -0.40263826, -0.09725586,  0.08863991,  0.18808259,
#         -0.13763784,  0.111093  , -0.32170793,  0.02562423, -0.58466774,
#          0.1693683 ,  0.10259921,  0.14301808, -0.17409126, -0.03000753,
#          0.03028326, -0.19418785, -0.181887  , -0.22661331,  0.05392344,
#          0.31712824,  0.01230068,  0.1140653 , -0.16751239, -0.12182011,
#          0.36573726,  0.05839619, -0.1338338 , -0.11736544, -0.46107197,
#          0.0888481 , -0.23291478, -0.21398734,  0.02428369,  0.16934176,
#         -0.01630282, -0.13186051, -0.10297088,  0.23145503,  0.10026459,
#          0.20981234, -0.21353427, -0.04703735,  0.06551048, -0.13916154,
#          0.04860361,  0.18505472,  0.02569259, -0.43754822,  0.11190655,
#         -0.03759518,  0.13700981, -0.01299792, -0.11227739, -0.2904454 ,
#          0.26578063,  0.05429471,  0.22586615, -0.3227128 ,  0.36335135,
#         -0.257039  ,  0.19217898,  0.39388105, -0.09358615,  0.32149178,
#          0.03192979,  0.06128597, -0.1087384 , -0.16450804,  0.08595674,
#         -0.22694406, -0.09426208, -0.22192203,  0.4452548 , -0.11461235,
#         -0.03340156,  0.07450905,  0.22526118,  0.34383038,  0.09495854,
#          0.3469324 ,  0.19299449,  0.06758343,  0.05944734,  0.44530863,
#          0.19433577,  0.1979726 , -0.18179245,  0.16287598,  0.02211647],
#        dtype=float32),
#  array([-0.20337397,  0.18884274,  0.09844666,  0.10238457,  0.06620675,
#         -0.41449296,  0.10221925,  0.4151716 , -0.20061293, -0.10718522,
#         -0.15450212, -0.3475579 , -0.07867198,  0.07984863,  0.16647114,
#         -0.1275867 ,  0.09591684, -0.2868587 ,  0.01451462, -0.51109415,
#          0.15240675,  0.08760042,  0.11759061, -0.14765449, -0.02472095,
#          0.02750756, -0.1690677 , -0.16596594, -0.19120272,  0.04393149,
#          0.27072567,  0.01017871,  0.0905911 , -0.14624181, -0.10407049,
#          0.31364274,  0.0449965 , -0.11810543, -0.097321  , -0.40361637,
#          0.0738886 , -0.19633722, -0.179795  ,  0.01458162,  0.13818258,
#         -0.02019099, -0.11594813, -0.08667283,  0.20039046,  0.08841134,
#          0.1771671 , -0.17866251, -0.03323872,  0.05477082, -0.11432349,
#          0.04584188,  0.1581476 ,  0.01759926, -0.37531593,  0.10489836,
#         -0.02761079,  0.11884197, -0.01182491, -0.08869369, -0.25367546,
#          0.22674493,  0.04389413,  0.19478726, -0.27314696,  0.31983832,
#         -0.21857712,  0.15589128,  0.33340016, -0.08897086,  0.2698303 ,
#          0.02498024,  0.04696193, -0.09339979, -0.14770943,  0.06379946,
#         -0.18289518, -0.07710758, -0.20019272,  0.37277716, -0.10450411,
#         -0.0262639 ,  0.06163071,  0.19958004,  0.29062366,  0.07553844,
#          0.30697322,  0.1572213 ,  0.05089492,  0.04161247,  0.3738894 ,
#          0.16124874,  0.16935617, -0.1675848 ,  0.14706671,  0.01369776],
#        dtype=float32),
#  array([-0.22916709,  0.23022027,  0.11904532,  0.13638096,  0.05922356,
#         -0.5200527 ,  0.13059072,  0.45430347, -0.23977318, -0.16593109,
#         -0.17382191, -0.40803292, -0.11408383,  0.08397487,  0.18081804,
#         -0.13916482,  0.11760021, -0.34534967,  0.03203149, -0.5861017 ,
#          0.14878994,  0.13309787,  0.1468469 , -0.18685709, -0.01007907,
#          0.03639062, -0.21184926, -0.15423112, -0.2393845 ,  0.0438023 ,
#          0.3190777 ,  0.01898731,  0.1157145 , -0.17355038, -0.11253548,
#          0.38187096,  0.11690902, -0.15623099, -0.14995033, -0.4993211 ,
#          0.07709695, -0.2631221 , -0.25858358,  0.01767818,  0.15820311,
#          0.00460099, -0.13848007, -0.09539657,  0.23849846,  0.09303324,
#          0.21072802, -0.25645682, -0.04902919,  0.09791425, -0.18701187,
#          0.03631106,  0.1841153 ,  0.00147611, -0.48210993,  0.13284326,
#         -0.03752161,  0.14019398,  0.01186408, -0.11840646, -0.3322128 ,
#          0.3028853 ,  0.02989752,  0.24045739, -0.3630887 ,  0.39382067,
#         -0.28420702,  0.25807893,  0.41310596, -0.11268384,  0.34581736,
#          0.03196705,  0.0411795 , -0.13475867, -0.16895162,  0.06850887,
#         -0.22816509, -0.11212464, -0.22517943,  0.4509428 , -0.08967936,
#         -0.01676744,  0.03755354,  0.2041196 ,  0.35708094,  0.14635047,
#          0.34561512,  0.20331262,  0.05717684,  0.03824709,  0.45269853,
#          0.18104672,  0.15036684, -0.2157464 ,  0.19239974,  0.03517158],
#        dtype=float32),
#  array([-0.30670977,  0.2963818 ,  0.15182479,  0.16336405,  0.09542399,
#         -0.645896  ,  0.1739854 ,  0.64842755, -0.31792766, -0.16771467,
#         -0.23317058, -0.5396112 , -0.12043256,  0.13110368,  0.2661398 ,
#         -0.1977931 ,  0.15295586, -0.43841186,  0.02992629, -0.8066154 ,
#          0.24464285,  0.13000394,  0.18222412, -0.23328105, -0.04777179,
#          0.04960088, -0.26251206, -0.259875  , -0.300745  ,  0.07288723,
#          0.43704504,  0.01856753,  0.15453978, -0.22778131, -0.1698833 ,
#          0.49330088,  0.06375956, -0.1733102 , -0.14545539, -0.6282844 ,
#          0.12445109, -0.30909267, -0.2779885 ,  0.03394711,  0.23578289,
#         -0.03612041, -0.17354016, -0.14787914,  0.3217474 ,  0.13381758,
#          0.27029833, -0.2736313 , -0.05183659,  0.07378258, -0.16724475,
#          0.06979715,  0.25094405,  0.04014787, -0.578997  ,  0.1545773 ,
#         -0.04840556,  0.19201936, -0.02256858, -0.1494139 , -0.38540667,
#          0.35976043,  0.07827134,  0.31103653, -0.42201057,  0.50323254,
#         -0.34018174,  0.23047844,  0.52949864, -0.13867517,  0.42813614,
#          0.04388955,  0.08740588, -0.13780268, -0.22456379,  0.10840792,
#         -0.30762583, -0.12374412, -0.30517918,  0.5988526 , -0.16532817,
#         -0.05238428,  0.11608792,  0.31759742,  0.46860918,  0.10636689,
#          0.47235855,  0.25508088,  0.09091519,  0.08527143,  0.59358656,
#          0.26427618,  0.28458044, -0.24595177,  0.21962564,  0.02217305],
#        dtype=float32),
#  array([-0.26356992,  0.24304914,  0.13507402,  0.13597696,  0.08898138,
#         -0.54389584,  0.14485691,  0.54826516, -0.26995715, -0.1508116 ,
#         -0.19846757, -0.46484515, -0.10516927,  0.10604601,  0.22631948,
#         -0.15824305,  0.13580208, -0.37185726,  0.02432488, -0.68392324,
#          0.20347796,  0.10991336,  0.16197182, -0.19566931, -0.02919477,
#          0.03995233, -0.21857412, -0.21292071, -0.26141855,  0.06263036,
#          0.37285128,  0.01934155,  0.1409448 , -0.19810134, -0.1450013 ,
#          0.4218917 ,  0.06537997, -0.15068583, -0.12373684, -0.52213496,
#          0.10622468, -0.26927763, -0.23817243,  0.03087429,  0.19996987,
#         -0.01919873, -0.15158728, -0.12292469,  0.25835013,  0.11658507,
#          0.22640847, -0.23471348, -0.0435918 ,  0.07226939, -0.14343445,
#          0.06057052,  0.20966296,  0.03516651, -0.48849225,  0.13909726,
#         -0.04016596,  0.16040103, -0.01829211, -0.12187008, -0.32634577,
#          0.3067913 ,  0.07286305,  0.26461253, -0.35204658,  0.42632842,
#         -0.28945082,  0.20417494,  0.4481689 , -0.11288536,  0.3666105 ,
#          0.03129328,  0.06378952, -0.12320063, -0.18439896,  0.09582122,
#         -0.25611517, -0.10063996, -0.25170597,  0.51474935, -0.13332744,
#         -0.02613147,  0.10541087,  0.25767788,  0.38867164,  0.0920805 ,
#          0.40191677,  0.21559668,  0.08257531,  0.07285526,  0.50536156,
#          0.22681452,  0.23042727, -0.21791035,  0.18100621,  0.0203262 ],
#        dtype=float32),
#  array([-0.27748922,  0.26466742,  0.13996893,  0.14753754,  0.08779143,
#         -0.59258485,  0.1553177 ,  0.5715537 , -0.28531536, -0.17372514,
#         -0.20739023, -0.4907669 , -0.11556087,  0.11135401,  0.23244824,
#         -0.16540678,  0.13993716, -0.39068243,  0.03152446, -0.71338964,
#          0.2066461 ,  0.1229496 ,  0.17715375, -0.21316727, -0.02590207,
#          0.03907681, -0.23597269, -0.21400349, -0.2800986 ,  0.06112972,
#          0.3936887 ,  0.02057378,  0.14719927, -0.2087374 , -0.14436008,
#          0.451289  ,  0.08596379, -0.16662195, -0.14414157, -0.5658178 ,
#          0.1063367 , -0.29452315, -0.26805398,  0.02697006,  0.20553124,
#         -0.01343665, -0.16151573, -0.12332518,  0.28106943,  0.12028919,
#          0.25400642, -0.2607247 , -0.05343666,  0.08617311, -0.167934  ,
#          0.05817585,  0.22515522,  0.02874394, -0.5316778 ,  0.14565189,
#         -0.04470636,  0.167933  , -0.00791784, -0.1303754 , -0.35882837,
#          0.3361533 ,  0.06668144,  0.28225315, -0.38969707,  0.45539308,
#         -0.31134102,  0.24027957,  0.48060977, -0.1170003 ,  0.3964405 ,
#          0.03582374,  0.0679507 , -0.13829862, -0.19639117,  0.0955211 ,
#         -0.27713534, -0.1097724 , -0.26913792,  0.54044014, -0.1335409 ,
#         -0.02996714,  0.09364635,  0.26407897,  0.42203712,  0.12275113,
#          0.42100933,  0.23738936,  0.08545366,  0.06883826,  0.536389  ,
#          0.2380895 ,  0.22950122, -0.22924136,  0.20039092,  0.02558288],
#        dtype=float32),
#  array([-0.2919776 ,  0.27777705,  0.15411992,  0.15492086,  0.09658348,
#         -0.6184164 ,  0.16216524,  0.611692  , -0.30388734, -0.17145368,
#         -0.21592925, -0.51817214, -0.11100432,  0.12186687,  0.25106248,
#         -0.17681502,  0.15123168, -0.40907067,  0.0313043 , -0.76654977,
#          0.2320572 ,  0.12247862,  0.18614627, -0.2276088 , -0.03526747,
#          0.04188792, -0.24452831, -0.23754565, -0.29228315,  0.06957264,
#          0.41992688,  0.02652131,  0.16128336, -0.2205199 , -0.15933938,
#          0.47296932,  0.06716768, -0.17044452, -0.1446224 , -0.5912994 ,
#          0.11611283, -0.3046622 , -0.26937267,  0.03085339,  0.22979115,
#         -0.0256847 , -0.17062445, -0.13583192,  0.29890078,  0.12845802,
#          0.2628621 , -0.25857633, -0.05639853,  0.07805217, -0.16108298,
#          0.06378934,  0.2356709 ,  0.04057542, -0.55091727,  0.1453238 ,
#         -0.05097216,  0.18139507, -0.01915017, -0.13743694, -0.3714633 ,
#          0.35141167,  0.08024628,  0.30024582, -0.4006779 ,  0.48047766,
#         -0.32600495,  0.2306733 ,  0.50821954, -0.11672826,  0.41524988,
#          0.03725561,  0.07997964, -0.14322612, -0.2058936 ,  0.11524707,
#         -0.29922086, -0.11799073, -0.28684762,  0.58203775, -0.15058947,
#         -0.04065187,  0.11156551,  0.28803447,  0.44638324,  0.11543807,
#          0.45081982,  0.24985388,  0.09150612,  0.08207028,  0.57195085,
#          0.25791165,  0.26328936, -0.23186192,  0.20233753,  0.01945469],
#        dtype=float32),
#  array([-2.19269723e-01,  2.24782497e-01,  1.19240619e-01,  1.26275137e-01,
#          5.60398661e-02, -4.84418929e-01,  1.29510522e-01,  4.47035849e-01,
#         -2.28493407e-01, -1.52711362e-01, -1.58882141e-01, -3.99821907e-01,
#         -9.13663879e-02,  8.31164569e-02,  1.84157372e-01, -1.33674100e-01,
#          1.08567566e-01, -3.21551293e-01,  3.72424871e-02, -5.66811264e-01,
#          1.55505151e-01,  1.14248693e-01,  1.41414300e-01, -1.77664533e-01,
#         -2.71149743e-02,  2.68590860e-02, -1.92347735e-01, -1.63771600e-01,
#         -2.28513435e-01,  4.31616604e-02,  3.13737333e-01,  1.92838255e-02,
#          1.23885728e-01, -1.58237889e-01, -1.12691224e-01,  3.67373407e-01,
#          8.71506110e-02, -1.36848509e-01, -1.32746056e-01, -4.67355281e-01,
#          8.04574341e-02, -2.45137736e-01, -2.32508436e-01,  2.25077923e-02,
#          1.58163488e-01,  1.29305321e-04, -1.31961584e-01, -9.62876156e-02,
#          2.35943690e-01,  9.83231738e-02,  2.11358115e-01, -2.24974304e-01,
#         -5.37620224e-02,  7.49563500e-02, -1.48386404e-01,  3.68061885e-02,
#          1.73462749e-01,  1.86887346e-02, -4.52325433e-01,  1.17230669e-01,
#         -5.15920222e-02,  1.33202076e-01,  1.43967464e-03, -1.13517597e-01,
#         -3.07831049e-01,  2.73273349e-01,  4.07340154e-02,  2.20073178e-01,
#         -3.32852602e-01,  3.66829962e-01, -2.55786031e-01,  2.24075690e-01,
#          3.94548565e-01, -9.85116884e-02,  3.30188096e-01,  3.55090201e-02,
#          5.91172911e-02, -1.30214706e-01, -1.61350131e-01,  8.12142119e-02,
#         -2.29385823e-01, -1.02924332e-01, -2.15105891e-01,  4.40429032e-01,
#         -1.01676188e-01, -2.69298404e-02,  4.51775752e-02,  2.00107962e-01,
#          3.48001808e-01,  1.25724703e-01,  3.33483636e-01,  1.99047893e-01,
#          7.27994964e-02,  5.30385785e-02,  4.32564974e-01,  1.85773969e-01,
#          1.71175197e-01, -1.87568113e-01,  1.71586722e-01,  2.46736333e-02],
#        dtype=float32),
#  array([-0.24509084,  0.25395802,  0.15029973,  0.15649194,  0.06598229,
#         -0.55533963,  0.1508425 ,  0.4941236 , -0.2639601 , -0.18216625,
#         -0.18810815, -0.45916277, -0.12683737,  0.09852555,  0.19958597,
#         -0.1550952 ,  0.12094203, -0.3629847 ,  0.02789078, -0.6292812 ,
#          0.16969685,  0.13889995,  0.15872522, -0.20787299, -0.02280704,
#          0.01908944, -0.23285946, -0.16540192, -0.25034648,  0.05386012,
#          0.35417247,  0.01736348,  0.12741178, -0.17698166, -0.12267499,
#          0.40665418,  0.12440021, -0.16159216, -0.16313136, -0.54041064,
#          0.08948767, -0.28189546, -0.26591763,  0.02507075,  0.16463444,
#          0.00953973, -0.14665233, -0.10419016,  0.25939435,  0.10683514,
#          0.24128129, -0.28155088, -0.06037596,  0.10893942, -0.18567231,
#          0.04908062,  0.2107742 ,  0.02180237, -0.528818  ,  0.14980593,
#         -0.05140153,  0.1399883 ,  0.01403155, -0.12262157, -0.3527421 ,
#          0.3114625 ,  0.05098976,  0.25482082, -0.3893532 ,  0.41979083,
#         -0.2974341 ,  0.26854745,  0.43918458, -0.11816666,  0.37014112,
#          0.03130044,  0.0508678 , -0.14743736, -0.1836447 ,  0.07599127,
#         -0.2514423 , -0.11233491, -0.2432956 ,  0.48672032, -0.09440335,
#         -0.0085663 ,  0.04292917,  0.21064879,  0.38853964,  0.14729404,
#          0.37914973,  0.21593548,  0.06367701,  0.03931973,  0.49334365,
#          0.18873647,  0.15938576, -0.23449704,  0.20504561,  0.04694882],
#        dtype=float32),
#  array([-0.2807367 ,  0.2917081 ,  0.15458852,  0.16992556,  0.07024065,
#         -0.64753634,  0.15938649,  0.56339765, -0.29660487, -0.21572787,
#         -0.21384305, -0.51356375, -0.13945256,  0.10149156,  0.23061188,
#         -0.17344452,  0.14170808, -0.42909837,  0.05107765, -0.7209247 ,
#          0.17689468,  0.1708795 ,  0.18241592, -0.24621785, -0.01305053,
#          0.03133585, -0.26111564, -0.18379028, -0.30150548,  0.05226586,
#          0.39653102,  0.0210453 ,  0.14504012, -0.19770427, -0.14374419,
#          0.47316447,  0.15183724, -0.20169522, -0.19406435, -0.62416846,
#          0.09925784, -0.3298476 , -0.3326736 ,  0.02135389,  0.1972782 ,
#          0.01486782, -0.17103013, -0.11981735,  0.30195   ,  0.11729345,
#          0.26912597, -0.32821354, -0.06478308,  0.11839496, -0.23643869,
#          0.04245955,  0.21659829, -0.00448947, -0.60346377,  0.15658064,
#         -0.05137653,  0.1704611 ,  0.02225273, -0.15102224, -0.4315421 ,
#          0.36737937,  0.02848429,  0.29705852, -0.46235633,  0.49842453,
#         -0.34711468,  0.33504355,  0.51549673, -0.14090618,  0.43969962,
#          0.05232812,  0.06099689, -0.17662641, -0.20970349,  0.08661884,
#         -0.28407216, -0.14693797, -0.28476903,  0.56942296, -0.10670529,
#         -0.02235756,  0.03045812,  0.23724154,  0.45161614,  0.19431633,
#          0.42475185,  0.25795203,  0.07179847,  0.04549761,  0.56318086,
#          0.22577278,  0.1841178 , -0.25826132,  0.23755038,  0.03701219],
#        dtype=float32),
#  array([-0.27158225,  0.25202623,  0.13147852,  0.1381091 ,  0.08718561,
#         -0.56605196,  0.14847027,  0.5596546 , -0.27536693, -0.15776739,
#         -0.20351036, -0.47720012, -0.10752037,  0.10372511,  0.22600743,
#         -0.1680423 ,  0.13566926, -0.37732846,  0.02882403, -0.69699264,
#          0.2084739 ,  0.1138875 ,  0.16991201, -0.20381439, -0.03042605,
#          0.03577698, -0.22335562, -0.21202958, -0.27035144,  0.06167445,
#          0.38673532,  0.0205334 ,  0.14428914, -0.20124722, -0.14228551,
#          0.43261948,  0.07326798, -0.15810439, -0.12762877, -0.5420064 ,
#          0.10994149, -0.28448558, -0.252593  ,  0.03055096,  0.19996741,
#         -0.01568871, -0.15206969, -0.12477833,  0.26833168,  0.11624633,
#          0.24340181, -0.24636523, -0.04661005,  0.08045866, -0.15233918,
#          0.06198877,  0.21814363,  0.02807163, -0.5054627 ,  0.14226332,
#         -0.04052755,  0.16117989, -0.01220779, -0.12434012, -0.33636752,
#          0.32224894,  0.07382423,  0.2731162 , -0.36937216,  0.43540847,
#         -0.29939508,  0.21634835,  0.4628256 , -0.11025208,  0.3776991 ,
#          0.03786134,  0.06564346, -0.12380031, -0.18865687,  0.0966126 ,
#         -0.26663944, -0.10356729, -0.25918433,  0.5257443 , -0.13748866,
#         -0.03058281,  0.10257106,  0.2565315 ,  0.40371177,  0.1052229 ,
#          0.41440123,  0.22789237,  0.08324349,  0.07049049,  0.5217207 ,
#          0.23247787,  0.22899632, -0.22037527,  0.18585509,  0.02674112],
#        dtype=float32),
#  array([-0.27422932,  0.2671838 ,  0.14027908,  0.16017339,  0.07702269,
#         -0.6209209 ,  0.15721774,  0.54522043, -0.28813362, -0.19240902,
#         -0.2085882 , -0.48985863, -0.1340137 ,  0.10191941,  0.21837233,
#         -0.16671737,  0.14895532, -0.4070711 ,  0.03412466, -0.70187086,
#          0.1831792 ,  0.15538445,  0.17597607, -0.22098336, -0.01592905,
#          0.03800435, -0.25076258, -0.18737662, -0.28626883,  0.05760396,
#          0.38737795,  0.01647689,  0.13921723, -0.20119849, -0.13542876,
#          0.44996542,  0.12762022, -0.18907613, -0.17265967, -0.5936829 ,
#          0.09931867, -0.31599072, -0.29835224,  0.02461376,  0.18520248,
#          0.00506751, -0.16618872, -0.1137681 ,  0.27969363,  0.11173356,
#          0.25413954, -0.30222425, -0.05188571,  0.11340075, -0.21572366,
#          0.0485217 ,  0.22700828,  0.00754748, -0.57052404,  0.16309133,
#         -0.04726913,  0.16323632,  0.00814251, -0.13745601, -0.38931587,
#          0.35988468,  0.04140033,  0.28950664, -0.42835516,  0.47115433,
#         -0.33909854,  0.29612347,  0.48940617, -0.13711278,  0.41093624,
#          0.0350761 ,  0.05192852, -0.15457244, -0.20055129,  0.07691036,
#         -0.27735996, -0.1258472 , -0.26522443,  0.54070824, -0.11192086,
#         -0.01732816,  0.05323072,  0.24052344,  0.42527902,  0.16072552,
#          0.4111842 ,  0.23958217,  0.06869373,  0.05227112,  0.535672  ,
#          0.21806513,  0.18464915, -0.25712776,  0.22419196,  0.04099366],
#        dtype=float32),
#  array([-0.29171085,  0.28881884,  0.16002247,  0.17182964,  0.07885464,
#         -0.6442758 ,  0.16830058,  0.56829745, -0.30135027, -0.20421027,
#         -0.21873713, -0.5272277 , -0.14179334,  0.10171556,  0.23311229,
#         -0.17458893,  0.14860809, -0.4308234 ,  0.03835776, -0.736917  ,
#          0.18784112,  0.16646457,  0.18564607, -0.2401009 , -0.0205887 ,
#          0.03508215, -0.26860458, -0.19547339, -0.29501832,  0.0585591 ,
#          0.41334185,  0.01445771,  0.14656346, -0.20427112, -0.14532109,
#          0.47374234,  0.14008325, -0.18923092, -0.17854528, -0.6279238 ,
#          0.11341719, -0.33534947, -0.3138922 ,  0.0273188 ,  0.19519846,
#          0.00723196, -0.17125756, -0.12182931,  0.29194093,  0.11486127,
#          0.27261937, -0.326956  , -0.06132913,  0.12265088, -0.2243887 ,
#          0.05494542,  0.24249487,  0.01614995, -0.61064607,  0.16916852,
#         -0.05706263,  0.16282742,  0.01879075, -0.1419287 , -0.41499808,
#          0.3677834 ,  0.04600136,  0.30149543, -0.447998  ,  0.4888682 ,
#         -0.35183907,  0.31386584,  0.516208  , -0.13717985,  0.4311411 ,
#          0.03718733,  0.05705849, -0.16691424, -0.2135761 ,  0.08598097,
#         -0.29065487, -0.1316652 , -0.27769962,  0.570499  , -0.11009409,
#         -0.01507862,  0.04895967,  0.24953762,  0.44952428,  0.16991967,
#          0.43401584,  0.253992  ,  0.07588185,  0.04856405,  0.57310987,
#          0.22999826,  0.19180387, -0.2663755 ,  0.238171  ,  0.04707829],
#        dtype=float32),
#  array([-0.27970064,  0.26303673,  0.13935247,  0.14757709,  0.08656148,
#         -0.5831777 ,  0.15702975,  0.56790704, -0.282396  , -0.1665083 ,
#         -0.20453772, -0.4914647 , -0.10812958,  0.10711991,  0.23249058,
#         -0.16897608,  0.14206752, -0.38555682,  0.03753162, -0.70858383,
#          0.21187994,  0.12432018,  0.17848481, -0.21174274, -0.03082907,
#          0.03288253, -0.23142262, -0.21474688, -0.27885476,  0.06070552,
#          0.39988837,  0.02158427,  0.14830717, -0.19771625, -0.14465861,
#          0.4462642 ,  0.07916775, -0.16004705, -0.13267846, -0.55789155,
#          0.11446996, -0.29596555, -0.26835325,  0.03084905,  0.20225741,
#         -0.00483258, -0.16145651, -0.12145257,  0.27672923,  0.12226921,
#          0.2568068 , -0.25507396, -0.05138619,  0.08469482, -0.16180632,
#          0.05773119,  0.22255522,  0.03277039, -0.5264538 ,  0.14420722,
#         -0.0521724 ,  0.16189864, -0.00482938, -0.13235858, -0.35446423,
#          0.32854027,  0.07153334,  0.27774724, -0.38436037,  0.4485614 ,
#         -0.3066303 ,  0.23746423,  0.48074216, -0.1114459 ,  0.39475122,
#          0.03824051,  0.07480115, -0.13788696, -0.19313876,  0.10083103,
#         -0.2807084 , -0.10682304, -0.26190126,  0.5433105 , -0.13686463,
#         -0.03333441,  0.09388484,  0.25515324,  0.4168877 ,  0.11888835,
#          0.41855377,  0.23697637,  0.08995425,  0.07108564,  0.5332035 ,
#          0.24196589,  0.23422238, -0.21863702,  0.19827995,  0.02711151],
#        dtype=float32),
#  array([-0.26444837,  0.25895727,  0.13970298,  0.14920577,  0.07836596,
#         -0.57421714,  0.1538751 ,  0.5464755 , -0.27257845, -0.1682847 ,
#         -0.19892804, -0.4864993 , -0.10997482,  0.10289123,  0.21770644,
#         -0.16401665,  0.14077622, -0.3835185 ,  0.03743411, -0.68783283,
#          0.20163454,  0.13218807,  0.16906498, -0.2112702 , -0.03596731,
#          0.02896198, -0.23101842, -0.20399892, -0.26804054,  0.05683335,
#          0.38045323,  0.02245242,  0.1423698 , -0.1953553 , -0.14517112,
#          0.43799245,  0.09170436, -0.16178875, -0.14694442, -0.5495395 ,
#          0.11152973, -0.29263332, -0.2598151 ,  0.03207625,  0.19869174,
#         -0.00111854, -0.16056311, -0.12456625,  0.27553695,  0.11512756,
#          0.24914454, -0.26082447, -0.0528465 ,  0.0837898 , -0.17281221,
#          0.05226435,  0.21643199,  0.02761212, -0.52723056,  0.14468603,
#         -0.05002131,  0.15541725, -0.00212407, -0.12999396, -0.3505659 ,
#          0.32126644,  0.05583355,  0.27397618, -0.38245687,  0.44231033,
#         -0.30769816,  0.23863368,  0.47064105, -0.10932394,  0.39080313,
#          0.03555983,  0.07092454, -0.14040236, -0.18900837,  0.09586432,
#         -0.27435508, -0.11587255, -0.26155463,  0.52586913, -0.12764947,
#         -0.02768448,  0.07803395,  0.24736308,  0.41287076,  0.12537093,
#          0.40900943,  0.2316354 ,  0.07808502,  0.06067412,  0.52228177,
#          0.22580229,  0.21700561, -0.21771215,  0.19990857,  0.03136443],
#        dtype=float32),
#  array([-2.41240248e-01,  2.36353472e-01,  1.22141026e-01,  1.31818116e-01,
#          6.79267123e-02, -5.29907703e-01,  1.36723563e-01,  4.80012000e-01,
#         -2.51390338e-01, -1.60309553e-01, -1.80309981e-01, -4.31889027e-01,
#         -1.08172670e-01,  8.68460387e-02,  1.99793234e-01, -1.42368287e-01,
#          1.22524664e-01, -3.49259138e-01,  3.30292881e-02, -6.14957333e-01,
#          1.63841739e-01,  1.26881331e-01,  1.53040498e-01, -1.93666339e-01,
#         -2.14651115e-02,  3.45949940e-02, -2.10676119e-01, -1.72128513e-01,
#         -2.46899486e-01,  4.63744253e-02,  3.37036729e-01,  1.61394849e-02,
#          1.23441018e-01, -1.75862119e-01, -1.19285837e-01,  3.95046979e-01,
#          9.88908783e-02, -1.52662799e-01, -1.42867908e-01, -5.07703125e-01,
#          9.03185830e-02, -2.66354054e-01, -2.53796577e-01,  2.46709846e-02,
#          1.70331478e-01,  4.62145748e-04, -1.40553430e-01, -1.02152057e-01,
#          2.42483839e-01,  1.03065908e-01,  2.21993297e-01, -2.50651717e-01,
#         -5.17591350e-02,  8.67048949e-02, -1.74078897e-01,  4.24636379e-02,
#          1.93901256e-01,  9.69932415e-03, -4.90839809e-01,  1.27448767e-01,
#         -4.47091535e-02,  1.43975407e-01,  4.50010458e-03, -1.21667422e-01,
#         -3.37266207e-01,  3.05527240e-01,  4.05664183e-02,  2.50459313e-01,
#         -3.63566995e-01,  4.03370082e-01, -2.83935875e-01,  2.47886360e-01,
#          4.28798109e-01, -1.08683363e-01,  3.55350435e-01,  3.98767926e-02,
#          5.86320423e-02, -1.34303287e-01, -1.77085593e-01,  8.24847370e-02,
#         -2.43408099e-01, -1.10406324e-01, -2.31902704e-01,  4.74525899e-01,
#         -1.07268795e-01, -2.27849633e-02,  5.19342944e-02,  2.18349338e-01,
#          3.73095214e-01,  1.36697903e-01,  3.60390902e-01,  2.14131549e-01,
#          6.88093454e-02,  5.18948361e-02,  4.71614033e-01,  1.98679224e-01,
#          1.81149393e-01, -2.07136303e-01,  1.89466044e-01,  2.60051042e-02],
#        dtype=float32),
#  array([-0.26110306,  0.25194785,  0.13732503,  0.13850991,  0.08215164,
#         -0.55917794,  0.155015  ,  0.5619227 , -0.27170822, -0.15217946,
#         -0.1992722 , -0.4812224 , -0.10409995,  0.10538697,  0.22378469,
#         -0.15945661,  0.13317662, -0.3805652 ,  0.03181353, -0.6879285 ,
#          0.2151164 ,  0.11580288,  0.15483241, -0.2031368 , -0.0385807 ,
#          0.03690727, -0.22134896, -0.22074856, -0.26857892,  0.05686408,
#          0.37593165,  0.01592948,  0.1369056 , -0.199012  , -0.1423926 ,
#          0.43012917,  0.05972104, -0.15439789, -0.12633765, -0.5347557 ,
#          0.10870043, -0.26831788, -0.24803455,  0.02271935,  0.205959  ,
#         -0.0247862 , -0.15295798, -0.11585943,  0.2758412 ,  0.12246936,
#          0.24568336, -0.23864402, -0.05752041,  0.06869818, -0.14883275,
#          0.06338995,  0.21524578,  0.03882002, -0.505542  ,  0.12791933,
#         -0.05623315,  0.1688931 , -0.02209265, -0.1324867 , -0.34350348,
#          0.31530172,  0.07097128,  0.26318708, -0.36623177,  0.4287394 ,
#         -0.29467013,  0.21196139,  0.45936942, -0.11842272,  0.37081587,
#          0.03526912,  0.07730664, -0.13393885, -0.19769847,  0.10888797,
#         -0.26827112, -0.10675561, -0.26449338,  0.5248566 , -0.1409492 ,
#         -0.04144606,  0.08913306,  0.2708567 ,  0.4079282 ,  0.10697242,
#          0.40462336,  0.23565726,  0.08675477,  0.07935455,  0.5197568 ,
#          0.23397191,  0.24167116, -0.20494054,  0.19332884,  0.01932961],
#        dtype=float32),
#  array([-0.22407259,  0.20345445,  0.11127808,  0.11379115,  0.07608718,
#         -0.4590875 ,  0.12130079,  0.4535835 , -0.22150207, -0.1242699 ,
#         -0.1703236 , -0.39116323, -0.08582255,  0.08688518,  0.18720423,
#         -0.13791715,  0.11299238, -0.31157938,  0.02607986, -0.5705435 ,
#          0.17404051,  0.09040827,  0.13688816, -0.1624145 , -0.02628928,
#          0.03099561, -0.1859323 , -0.18417351, -0.2160395 ,  0.04747525,
#          0.31308475,  0.01680236,  0.11355979, -0.15723138, -0.11632483,
#          0.35046995,  0.0398192 , -0.12706436, -0.09787595, -0.44223878,
#          0.09254689, -0.23196425, -0.19953968,  0.02501918,  0.16092615,
#         -0.01387105, -0.13252771, -0.10276221,  0.21568571,  0.09601438,
#          0.19535168, -0.20012255, -0.03080925,  0.06365661, -0.12434644,
#          0.05361622,  0.17838925,  0.03320694, -0.41367754,  0.11446092,
#         -0.03857617,  0.13043445, -0.01303142, -0.1025014 , -0.27742055,
#          0.25160894,  0.06383584,  0.2235413 , -0.29646313,  0.36112484,
#         -0.24423887,  0.16984786,  0.37642694, -0.09316137,  0.30518588,
#          0.02881306,  0.06230052, -0.10073459, -0.1549488 ,  0.07991935,
#         -0.21924035, -0.08248956, -0.20706218,  0.434639  , -0.11493862,
#         -0.02922153,  0.08525255,  0.2168007 ,  0.3265721 ,  0.07702351,
#          0.33877206,  0.17880045,  0.06629618,  0.06310656,  0.4233532 ,
#          0.19709103,  0.19664265, -0.17633705,  0.15182547,  0.01964168],
#        dtype=float32),
#  array([-0.31636837,  0.28048575,  0.14845084,  0.14891602,  0.10909463,
#         -0.62891126,  0.16578846,  0.6340294 , -0.31393996, -0.1684878 ,
#         -0.2309715 , -0.5385502 , -0.10947056,  0.11954521,  0.27222833,
#         -0.19084898,  0.16204406, -0.4162101 ,  0.02768009, -0.79631996,
#          0.24510379,  0.12287331,  0.19628863, -0.22604775, -0.03584351,
#          0.0425856 , -0.24281783, -0.25250787, -0.3017166 ,  0.06822973,
#          0.4427305 ,  0.02739838,  0.165454  , -0.22408316, -0.16419652,
#          0.48639464,  0.05926202, -0.16720769, -0.1346046 , -0.596912  ,
#          0.12718442, -0.31795377, -0.27136227,  0.04169437,  0.23702586,
#         -0.02276804, -0.17432189, -0.13936357,  0.2991723 ,  0.13502009,
#          0.27412254, -0.2619179 , -0.05829892,  0.06859227, -0.16067189,
#          0.06978523,  0.24885814,  0.0468457 , -0.5577196 ,  0.14645024,
#         -0.0486183 ,  0.18497579, -0.01160453, -0.14012823, -0.36843777,
#          0.3541365 ,  0.09204836,  0.3094484 , -0.4040156 ,  0.48797625,
#         -0.32568175,  0.22956178,  0.51905215, -0.11347514,  0.4278241 ,
#          0.04615875,  0.08963046, -0.1382019 , -0.21312086,  0.12009169,
#         -0.3092124 , -0.11612797, -0.28957105,  0.6046804 , -0.16438195,
#         -0.04326306,  0.12545714,  0.2971645 ,  0.45929772,  0.10368997,
#          0.46977344,  0.26203123,  0.10503779,  0.09253544,  0.5953102 ,
#          0.28104207,  0.28999543, -0.2278628 ,  0.20000117,  0.02361732],
#        dtype=float32),
#  array([-0.21013492,  0.20508237,  0.10338137,  0.11968778,  0.0613297 ,
#         -0.47168133,  0.11803871,  0.41819295, -0.22000585, -0.14365265,
#         -0.15743975, -0.37708586, -0.10240731,  0.07596577,  0.16787356,
#         -0.12602276,  0.11320969, -0.3131139 ,  0.02806397, -0.5403888 ,
#          0.13667016,  0.11838791,  0.13030463, -0.16750349, -0.01194446,
#          0.03361107, -0.1877319 , -0.14528264, -0.21629141,  0.04073019,
#          0.2977422 ,  0.01319598,  0.10603883, -0.1535317 , -0.10218661,
#          0.34308252,  0.09196608, -0.14024416, -0.12671177, -0.45259345,
#          0.07854472, -0.23633946, -0.22759268,  0.02102362,  0.14569455,
#          0.00054819, -0.13205299, -0.08730802,  0.21013004,  0.08394125,
#          0.18880028, -0.22725643, -0.0404142 ,  0.08266253, -0.15914069,
#          0.03814637,  0.17287014,  0.00627631, -0.4320644 ,  0.11985075,
#         -0.03609683,  0.12544324,  0.0052667 , -0.10446522, -0.296571  ,
#          0.27498388,  0.03490126,  0.22150244, -0.321245  ,  0.35525805,
#         -0.2567698 ,  0.22022027,  0.37491643, -0.10142407,  0.3122705 ,
#          0.02684624,  0.04204198, -0.11915893, -0.15163536,  0.06172787,
#         -0.20976005, -0.09506953, -0.20219426,  0.41497183, -0.08532009,
#         -0.01610404,  0.04334556,  0.18917511,  0.32846716,  0.12269188,
#          0.3125928 ,  0.18455827,  0.05597296,  0.04024911,  0.41168654,
#          0.1706735 ,  0.14798307, -0.1907797 ,  0.17290604,  0.02756587],
#        dtype=float32),
#  array([-0.29419118,  0.26350456,  0.14495738,  0.14148438,  0.09474564,
#         -0.5852503 ,  0.15763617,  0.5936106 , -0.2903669 , -0.15894464,
#         -0.21572559, -0.5088147 , -0.10322177,  0.12344117,  0.24878225,
#         -0.17108183,  0.15023805, -0.3781295 ,  0.03542551, -0.7439448 ,
#          0.24088998,  0.10446031,  0.18975441, -0.21196619, -0.03302136,
#          0.04263891, -0.22705509, -0.24043049, -0.27760842,  0.07174803,
#          0.42154655,  0.02785869,  0.15972368, -0.20454483, -0.14971103,
#          0.456335  ,  0.04300043, -0.14854673, -0.11385058, -0.5600401 ,
#          0.1313332 , -0.29782692, -0.24676347,  0.03083232,  0.21409106,
#         -0.01774909, -0.16822028, -0.13640498,  0.28091493,  0.12531367,
#          0.26291108, -0.2391152 , -0.04986221,  0.0721704 , -0.14071879,
#          0.07509565,  0.23639812,  0.05186641, -0.5214752 ,  0.14348173,
#         -0.05494206,  0.1691444 , -0.01459899, -0.1262301 , -0.33927128,
#          0.32531968,  0.09875309,  0.28547773, -0.36808857,  0.4628499 ,
#         -0.30301905,  0.19938485,  0.4873605 , -0.09575105,  0.39395943,
#          0.03796149,  0.08472352, -0.12538894, -0.19352722,  0.11807413,
#         -0.295967  , -0.09916107, -0.2599369 ,  0.5610321 , -0.15209307,
#         -0.03981107,  0.1291375 ,  0.27430692,  0.4237976 ,  0.08821478,
#          0.44014502,  0.23524499,  0.0963126 ,  0.08483458,  0.543382  ,
#          0.2614017 ,  0.27197927, -0.21887474,  0.1791285 ,  0.02983452],
#        dtype=float32),
#  array([-0.2775365 ,  0.29277873,  0.15304059,  0.16369204,  0.06734651,
#         -0.62768924,  0.17514223,  0.59008   , -0.2959593 , -0.19399174,
#         -0.20095524, -0.51166934, -0.12303364,  0.11223587,  0.23625535,
#         -0.17315067,  0.13685052, -0.4109714 ,  0.04570305, -0.73642147,
#          0.2125366 ,  0.14744626,  0.17496663, -0.2273597 , -0.03481949,
#          0.03259518, -0.24384859, -0.21097744, -0.29662055,  0.05958806,
#          0.39840308,  0.02914937,  0.16687706, -0.22762935, -0.14618295,
#          0.4749788 ,  0.10852686, -0.17741579, -0.17856294, -0.6045637 ,
#          0.09690028, -0.30807036, -0.29646012,  0.01892277,  0.2232009 ,
#         -0.00385644, -0.17077182, -0.12072461,  0.31690413,  0.13107657,
#          0.2772267 , -0.2700918 , -0.08157932,  0.08466946, -0.18430758,
#          0.03775559,  0.22824396,  0.02893006, -0.5824222 ,  0.13895066,
#         -0.06397147,  0.18101907, -0.00511003, -0.15570317, -0.4018516 ,
#          0.35596836,  0.05898214,  0.28547722, -0.44030848,  0.4718948 ,
#         -0.3308096 ,  0.27907646,  0.5076008 , -0.12664747,  0.43268642,
#          0.04054365,  0.08636463, -0.16896634, -0.21434613,  0.10902776,
#         -0.3063494 , -0.13456582, -0.2915541 ,  0.5702195 , -0.1344726 ,
#         -0.04884013,  0.06075735,  0.26501015,  0.45593828,  0.16559646,
#          0.42546952,  0.25832462,  0.0959206 ,  0.07222792,  0.5679691 ,
#          0.23943575,  0.22875626, -0.231101  ,  0.22226045,  0.03143738],
#        dtype=float32),
#  array([-0.24675313,  0.24040289,  0.12897506,  0.13018714,  0.07858915,
#         -0.52513635,  0.14341001,  0.5270392 , -0.25488764, -0.13933213,
#         -0.19105928, -0.4436502 , -0.0979571 ,  0.10437204,  0.21587484,
#         -0.15720941,  0.12493436, -0.35232598,  0.02900122, -0.6515411 ,
#          0.20072858,  0.10445829,  0.15262756, -0.19198589, -0.03435094,
#          0.03576887, -0.2111363 , -0.20912576, -0.25166708,  0.05755718,
#          0.35789815,  0.01975234,  0.13083301, -0.19010143, -0.13518961,
#          0.3997351 ,  0.05060908, -0.14126688, -0.12075685, -0.5073079 ,
#          0.09747139, -0.25064802, -0.22391045,  0.02462552,  0.1897277 ,
#         -0.02378303, -0.14515638, -0.11746105,  0.26247287,  0.11348657,
#          0.22624412, -0.22078314, -0.04768071,  0.06149853, -0.13236499,
#          0.05777859,  0.20174341,  0.03414328, -0.47174317,  0.12266465,
#         -0.04484147,  0.15769263, -0.01568294, -0.12023842, -0.3151008 ,
#          0.29653934,  0.06260252,  0.24697463, -0.3400121 ,  0.40203604,
#         -0.27672568,  0.1935094 ,  0.43133935, -0.10197265,  0.35115838,
#          0.03417752,  0.07446159, -0.11394773, -0.18264134,  0.09671898,
#         -0.25277546, -0.09996766, -0.24903384,  0.48679227, -0.13315004,
#         -0.04101768,  0.09413539,  0.25200525,  0.38259244,  0.09515773,
#          0.38859448,  0.21263048,  0.07629882,  0.06795246,  0.48666582,
#          0.21535763,  0.22788946, -0.19616416,  0.17346916,  0.02090588],
#        dtype=float32),
#  array([-0.26051965,  0.24174841,  0.12611112,  0.13124783,  0.08618508,
#         -0.5299274 ,  0.1333287 ,  0.5266195 , -0.26098698, -0.13275173,
#         -0.20453653, -0.4457794 , -0.10576245,  0.09956357,  0.21600628,
#         -0.16206925,  0.12673077, -0.37080157,  0.02397998, -0.6506179 ,
#          0.1900797 ,  0.11813554,  0.15217674, -0.18739739, -0.03155814,
#          0.04094215, -0.22670858, -0.2094471 , -0.24757355,  0.05879268,
#          0.35656452,  0.01227609,  0.11184296, -0.17515746, -0.13773786,
#          0.3968517 ,  0.05638767, -0.14900395, -0.10985433, -0.5171697 ,
#          0.10447258, -0.25682238, -0.23313706,  0.02619118,  0.1802688 ,
#         -0.02386059, -0.14943029, -0.11651196,  0.2545251 ,  0.10406238,
#          0.221007  , -0.23747118, -0.03264316,  0.07172574, -0.15530479,
#          0.06200434,  0.20875128,  0.02452996, -0.47639054,  0.12941585,
#         -0.04043954,  0.15175976, -0.01956363, -0.11910085, -0.3218334 ,
#          0.29487798,  0.058038  ,  0.25718343, -0.3454139 ,  0.41037828,
#         -0.2858199 ,  0.20081945,  0.42793566, -0.1213493 ,  0.34700724,
#          0.03007598,  0.05801263, -0.11474782, -0.18442827,  0.08098036,
#         -0.23689264, -0.1032863 , -0.2431408 ,  0.48821256, -0.13209558,
#         -0.03314476,  0.08719041,  0.25282684,  0.37385923,  0.08671917,
#          0.38789225,  0.20944086,  0.06542956,  0.05885281,  0.48689002,
#          0.21795467,  0.22131972, -0.213709  ,  0.18344042,  0.02492869],
#        dtype=float32),
#  array([-0.3032153 ,  0.27559823,  0.15054245,  0.15126571,  0.10290882,
#         -0.6305549 ,  0.16069517,  0.62313384, -0.3088005 , -0.17832851,
#         -0.23002887, -0.53314865, -0.12026618,  0.12117936,  0.25924003,
#         -0.18336764,  0.15658455, -0.41919824,  0.03597313, -0.7736789 ,
#          0.23272108,  0.12264352,  0.19857517, -0.23348367, -0.0285938 ,
#          0.04104493, -0.25267023, -0.23849213, -0.29299602,  0.07343882,
#          0.4364835 ,  0.02284407,  0.1564823 , -0.21468946, -0.15761183,
#          0.4829248 ,  0.07252322, -0.17042758, -0.13172504, -0.59814656,
#          0.13190581, -0.32157934, -0.2799588 ,  0.03734843,  0.22101769,
#         -0.01283351, -0.1734552 , -0.13993283,  0.29657972,  0.12889639,
#          0.27240258, -0.27284926, -0.04299373,  0.08944666, -0.1647727 ,
#          0.07454321,  0.24155368,  0.03960413, -0.5540984 ,  0.16004586,
#         -0.04564396,  0.17860788, -0.01244877, -0.13418959, -0.37156397,
#          0.35378715,  0.0873537 ,  0.3014743 , -0.40348142,  0.49538338,
#         -0.32762146,  0.23388205,  0.5151139 , -0.11983654,  0.4211135 ,
#          0.0404765 ,  0.06969626, -0.1384995 , -0.20921023,  0.1089578 ,
#         -0.29843825, -0.11041757, -0.28824532,  0.5837995 , -0.14943863,
#         -0.0289131 ,  0.11892494,  0.2875353 ,  0.4495137 ,  0.11372036,
#          0.4651196 ,  0.24932715,  0.0883991 ,  0.07971824,  0.5748574 ,
#          0.26503193,  0.26492915, -0.2378774 ,  0.20668526,  0.02632158],
#        dtype=float32),
#  array([-0.21109046,  0.19606337,  0.1072614 ,  0.11049923,  0.06640578,
#         -0.4422568 ,  0.11401987,  0.43327734, -0.21375073, -0.12350308,
#         -0.1586708 , -0.37138188, -0.08323558,  0.08654756,  0.17739779,
#         -0.12671128,  0.10738263, -0.2952303 ,  0.02407368, -0.54268545,
#          0.1625708 ,  0.09002537,  0.13070641, -0.16086619, -0.0231823 ,
#          0.03042975, -0.17692956, -0.16806066, -0.2087488 ,  0.0459754 ,
#          0.30182302,  0.0172622 ,  0.11227162, -0.15595287, -0.11374815,
#          0.3370456 ,  0.05490347, -0.12434316, -0.10136962, -0.4278464 ,
#          0.08576166, -0.22090968, -0.19644302,  0.01933612,  0.15728979,
#         -0.01416441, -0.121976  , -0.09615732,  0.20731765,  0.09258472,
#          0.18978482, -0.1898759 , -0.03849138,  0.06048731, -0.11851278,
#          0.04722321,  0.16774254,  0.02584355, -0.39908093,  0.10561971,
#         -0.03617493,  0.125571  , -0.01029609, -0.09559503, -0.265622  ,
#          0.2500116 ,  0.05484337,  0.21335317, -0.28644854,  0.3431667 ,
#         -0.23317699,  0.17023054,  0.36296102, -0.0874569 ,  0.29710528,
#          0.02589016,  0.05599218, -0.10240033, -0.1480128 ,  0.07673229,
#         -0.21060094, -0.08289748, -0.20180462,  0.41405028, -0.10568201,
#         -0.02522893,  0.07821364,  0.20422854,  0.31491175,  0.08260973,
#          0.3231281 ,  0.17376289,  0.06727571,  0.05603921,  0.4044817 ,
#          0.18524833,  0.18087049, -0.17240952,  0.14675649,  0.01912127],
#        dtype=float32),
#  array([-0.31181607,  0.29592916,  0.15931958,  0.16170682,  0.09243456,
#         -0.651234  ,  0.16721493,  0.6361768 , -0.31245768, -0.19142869,
#         -0.23308608, -0.5482546 , -0.11718318,  0.11888993,  0.26472658,
#         -0.19161578,  0.16001019, -0.44641566,  0.03808055, -0.7997763 ,
#          0.22486651,  0.14180322,  0.19599323, -0.2395299 , -0.039578  ,
#          0.04027971, -0.26949275, -0.24950318, -0.29796267,  0.07513555,
#          0.44366914,  0.02070148,  0.16158693, -0.20404446, -0.16970068,
#          0.5013375 ,  0.08026582, -0.18676473, -0.15227138, -0.6325776 ,
#          0.12842983, -0.3309128 , -0.29832676,  0.03771491,  0.2205073 ,
#         -0.01493346, -0.1838446 , -0.14471751,  0.29770282,  0.1364869 ,
#          0.27737615, -0.29407567, -0.05094926,  0.09945706, -0.1869315 ,
#          0.07022118,  0.24878669,  0.03015485, -0.5912029 ,  0.16093549,
#         -0.05704758,  0.17504533, -0.00965626, -0.14430761, -0.40091836,
#          0.3693035 ,  0.07354894,  0.31024322, -0.43035206,  0.50089836,
#         -0.3483827 ,  0.26714227,  0.5345693 , -0.13124299,  0.43247774,
#          0.04763039,  0.08179381, -0.15102226, -0.2195144 ,  0.10600665,
#         -0.30047274, -0.12591818, -0.29038993,  0.60779333, -0.15525682,
#         -0.02998434,  0.1004678 ,  0.28288114,  0.45980403,  0.12442047,
#          0.4743246 ,  0.25942034,  0.08541885,  0.08019827,  0.5941859 ,
#          0.26485068,  0.26017243, -0.25797987,  0.22158676,  0.02951413],
#        dtype=float32),
#  array([-0.2715153 ,  0.23075359,  0.13425045,  0.1250121 ,  0.09789582,
#         -0.5251612 ,  0.13355173,  0.53809315, -0.26314962, -0.14370583,
#         -0.20179424, -0.46137366, -0.09170796,  0.1072509 ,  0.22690913,
#         -0.15749094,  0.14190334, -0.34732404,  0.02546767, -0.6709558 ,
#          0.20897275,  0.09880328,  0.17451565, -0.19696975, -0.02431278,
#          0.03489715, -0.20799595, -0.21703754, -0.24537206,  0.06875584,
#          0.39046428,  0.02067017,  0.13143438, -0.16651914, -0.13818051,
#          0.4138828 ,  0.03970362, -0.13673183, -0.08468094, -0.49812508,
#          0.13406096, -0.2776712 , -0.22864518,  0.03698809,  0.18473527,
#         -0.00913434, -0.15473507, -0.12184994,  0.23079751,  0.10742646,
#          0.23523182, -0.22311923, -0.02653106,  0.0759224 , -0.12522443,
#          0.07695653,  0.21434967,  0.04563933, -0.4620313 ,  0.14443746,
#         -0.04409524,  0.1408112 , -0.01057362, -0.10521828, -0.29932415,
#          0.29105943,  0.09330495,  0.26082954, -0.31631434,  0.41982082,
#         -0.2770368 ,  0.17714596,  0.4399863 , -0.09205275,  0.34969425,
#          0.03017077,  0.06585081, -0.10947419, -0.16809124,  0.09753779,
#         -0.25343072, -0.07389097, -0.23048574,  0.5035565 , -0.1363545 ,
#         -0.01429697,  0.1306344 ,  0.2396624 ,  0.3764624 ,  0.06910381,
#          0.4083284 ,  0.2074148 ,  0.08228825,  0.07252868,  0.4872003 ,
#          0.2426486 ,  0.23836923, -0.20464839,  0.16421412,  0.0268166 ],
#        dtype=float32),
#  array([-0.30898294,  0.2844954 ,  0.15781768,  0.1532947 ,  0.10940442,
#         -0.63878924,  0.16478944,  0.64998287, -0.31686622, -0.17663488,
#         -0.24100542, -0.5444033 , -0.12315088,  0.1285691 ,  0.2700096 ,
#         -0.18568756,  0.15732548, -0.42663854,  0.02588697, -0.7961755 ,
#          0.24054001,  0.11555745,  0.19795485, -0.24413879, -0.03257331,
#          0.03990843, -0.25848365, -0.25041845, -0.30437726,  0.07553595,
#          0.44676456,  0.02647913,  0.16102137, -0.23105802, -0.16795637,
#          0.49165955,  0.07475644, -0.17526305, -0.14036793, -0.6108077 ,
#          0.12897609, -0.31755537, -0.2779831 ,  0.03862811,  0.23338692,
#         -0.02128566, -0.1798363 , -0.14361624,  0.3039059 ,  0.14004481,
#          0.27953765, -0.27304056, -0.05076104,  0.09052772, -0.16291164,
#          0.08012372,  0.24675079,  0.04138931, -0.56860626,  0.16472256,
#         -0.04340789,  0.18356475, -0.01100008, -0.13647442, -0.3741506 ,
#          0.36536667,  0.09271325,  0.3096564 , -0.40571094,  0.50384   ,
#         -0.3367711 ,  0.23647003,  0.52418864, -0.12166127,  0.4247019 ,
#          0.0376667 ,  0.07966784, -0.14156269, -0.21239758,  0.1156681 ,
#         -0.3038874 , -0.11323177, -0.3002704 ,  0.59823716, -0.15954229,
#         -0.03211604,  0.12947457,  0.30251926,  0.45992872,  0.11234654,
#          0.4814659 ,  0.26096383,  0.09107346,  0.08213603,  0.5949282 ,
#          0.27640882,  0.2709908 , -0.24721678,  0.20540516,  0.02644564],
#        dtype=float32),
#  array([-0.27762496,  0.25718856,  0.13673788,  0.13576697,  0.09601749,
#         -0.56622297,  0.15021247,  0.58136624, -0.2765095 , -0.15723272,
#         -0.20333576, -0.484994  , -0.09987313,  0.11441895,  0.24162963,
#         -0.15900259,  0.14048418, -0.37412044,  0.0302975 , -0.7211635 ,
#          0.22153468,  0.10169445,  0.17405763, -0.20434295, -0.03741015,
#          0.03612198, -0.22202106, -0.23219912, -0.2675308 ,  0.06466249,
#          0.3982786 ,  0.02210083,  0.1543845 , -0.2071678 , -0.14772628,
#          0.4393071 ,  0.04931696, -0.14744057, -0.12289442, -0.5364791 ,
#          0.11078089, -0.27488703, -0.23803918,  0.02937787,  0.21486133,
#         -0.02935651, -0.15425354, -0.13107063,  0.27168033,  0.1284225 ,
#          0.24974261, -0.2290206 , -0.0546347 ,  0.06724431, -0.1318319 ,
#          0.06469773,  0.2289688 ,  0.04725601, -0.49805462,  0.13395767,
#         -0.04830602,  0.1673126 , -0.02212934, -0.12397855, -0.3303947 ,
#          0.31647956,  0.09037024,  0.27616596, -0.35274345,  0.44071776,
#         -0.2949918 ,  0.19062093,  0.4690306 , -0.09955577,  0.37940276,
#          0.02927651,  0.08201406, -0.12221795, -0.19423336,  0.11181119,
#         -0.28201035, -0.09685842, -0.25872552,  0.5401892 , -0.15135808,
#         -0.03767055,  0.12151101,  0.2771954 ,  0.4115973 ,  0.089075  ,
#          0.42688227,  0.2320431 ,  0.09338083,  0.08676397,  0.5372782 ,
#          0.249219  ,  0.263039  , -0.21096009,  0.17558275,  0.01812487],
#        dtype=float32),
#  array([-0.31238917,  0.28569406,  0.15462014,  0.1583649 ,  0.10164618,
#         -0.6379482 ,  0.15981899,  0.63345265, -0.31194448, -0.17981693,
#         -0.23359871, -0.5401738 , -0.11793356,  0.12447309,  0.26180258,
#         -0.18196501,  0.15926751, -0.42601117,  0.03505075, -0.79612917,
#          0.23855872,  0.12665315,  0.19593571, -0.23415889, -0.03237862,
#          0.04511586, -0.25945356, -0.2461387 , -0.29992664,  0.07668869,
#          0.44322312,  0.02384363,  0.16411129, -0.22407681, -0.16481282,
#          0.4890193 ,  0.07049561, -0.17540492, -0.13832389, -0.6087873 ,
#          0.12922019, -0.3208558 , -0.27975225,  0.03373406,  0.22666305,
#         -0.0209916 , -0.176717  , -0.14257775,  0.29924032,  0.13011168,
#          0.27732894, -0.27326605, -0.05290674,  0.08868973, -0.16401061,
#          0.07386249,  0.24979882,  0.04224598, -0.5697935 ,  0.16429281,
#         -0.05019313,  0.18537809, -0.01605497, -0.13361458, -0.37449786,
#          0.35835648,  0.09051576,  0.30816367, -0.40557566,  0.49889052,
#         -0.33606553,  0.23511395,  0.52176267, -0.12055423,  0.42679608,
#          0.03983302,  0.0757662 , -0.14144695, -0.2103272 ,  0.11274643,
#         -0.30451214, -0.11656348, -0.28876865,  0.59993005, -0.15611075,
#         -0.03015708,  0.12448592,  0.29375267,  0.45804435,  0.1094375 ,
#          0.47489128,  0.2535362 ,  0.09264076,  0.08499052,  0.58717704,
#          0.26471135,  0.26994893, -0.24751414,  0.20673338,  0.03087102],
#        dtype=float32),
#  array([-0.32510602,  0.30096963,  0.16153727,  0.16069482,  0.10543606,
#         -0.65936095,  0.18083555,  0.6705947 , -0.3274864 , -0.17416333,
#         -0.24482897, -0.56522757, -0.12594584,  0.12848127,  0.2763122 ,
#         -0.19791538,  0.16139224, -0.44441172,  0.03596847, -0.8310828 ,
#          0.25619677,  0.12736298,  0.20169851, -0.2369451 , -0.04463257,
#          0.04485269, -0.26492694, -0.26618043, -0.31489176,  0.07499107,
#          0.46210086,  0.0221945 ,  0.16897622, -0.2367431 , -0.1734251 ,
#          0.5117017 ,  0.06456548, -0.17602444, -0.14569789, -0.63354033,
#          0.13570723, -0.33001363, -0.2860246 ,  0.03901945,  0.24278854,
#         -0.03217251, -0.18275814, -0.15116554,  0.31937858,  0.1427494 ,
#          0.2912674 , -0.27975464, -0.0547766 ,  0.08360475, -0.16870701,
#          0.07452832,  0.26161027,  0.04731776, -0.594926  ,  0.15448615,
#         -0.05374335,  0.19300412, -0.02213806, -0.15080287, -0.39244378,
#          0.37044692,  0.09682628,  0.31973344, -0.42566893,  0.51470554,
#         -0.34967768,  0.24160618,  0.5471856 , -0.12839814,  0.44604072,
# ...
#          2.03335613e-01, -7.47061148e-03, -1.57703683e-01, -1.21232107e-01,
#          2.85770923e-01,  1.22147478e-01,  2.54785925e-01, -2.72314757e-01,
#         -6.04550317e-02,  9.11244899e-02, -1.85207948e-01,  4.96828705e-02,
#          2.15925574e-01,  2.13867091e-02, -5.47022820e-01,  1.38560861e-01,
#         -4.77092899e-02,  1.67237028e-01,  3.51182331e-04, -1.41365364e-01,
#         -3.69744241e-01,  3.36573541e-01,  5.95735684e-02,  2.77528614e-01,
#         -4.10569012e-01,  4.51660633e-01, -3.14972341e-01,  2.62986004e-01,
#          4.77021694e-01, -1.20755397e-01,  3.98255497e-01,  4.25217897e-02,
#          6.90557212e-02, -1.47311360e-01, -2.00655967e-01,  9.71990824e-02,
#         -2.75516033e-01, -1.20496854e-01, -2.73244530e-01,  5.36498427e-01,
#         -1.22787416e-01, -3.72637473e-02,  6.37069419e-02,  2.54275978e-01,
#          4.27726984e-01,  1.42981991e-01,  4.12688345e-01,  2.39468023e-01,
#          7.82182887e-02,  6.18340299e-02,  5.36129057e-01,  2.25352556e-01,
#          2.16889173e-01, -2.28695944e-01,  2.04830483e-01,  2.92291548e-02],
#        dtype=float32),
#  array([-0.23046623,  0.22251365,  0.12086075,  0.1290313 ,  0.06920773,
#         -0.4938842 ,  0.13959722,  0.47486794, -0.24032243, -0.14362746,
#         -0.17104544, -0.41067916, -0.09561756,  0.09372803,  0.19298011,
#         -0.13954502,  0.11900988, -0.32884067,  0.02829122, -0.59780216,
#          0.1737884 ,  0.11282104,  0.14833514, -0.1785833 , -0.02048639,
#          0.02648184, -0.19891027, -0.1754032 , -0.23258185,  0.05062424,
#          0.32808658,  0.01737628,  0.12365537, -0.16351324, -0.1227375 ,
#          0.37698025,  0.07550575, -0.13982585, -0.12945856, -0.48537403,
#          0.08691457, -0.24554975, -0.2275987 ,  0.02378858,  0.16974886,
#         -0.00231079, -0.14004898, -0.09942471,  0.23597437,  0.09984609,
#          0.21132998, -0.22978517, -0.05253096,  0.07323163, -0.1483464 ,
#          0.04559584,  0.18487687,  0.01800371, -0.4564085 ,  0.11804778,
#         -0.04563068,  0.13728179, -0.00288708, -0.11505321, -0.30921924,
#          0.2829047 ,  0.05126938,  0.23705965, -0.3397388 ,  0.38340944,
#         -0.26555803,  0.21323246,  0.40518743, -0.10168989,  0.33264104,
#          0.0288912 ,  0.06034316, -0.12217978, -0.16874701,  0.08424273,
#         -0.23270339, -0.10145257, -0.2262604 ,  0.45757124, -0.10749523,
#         -0.02820785,  0.07036397,  0.21584974,  0.35240877,  0.11087812,
#          0.34767568,  0.19899268,  0.06580687,  0.05220596,  0.4501684 ,
#          0.19492157,  0.18882968, -0.19209927,  0.17362422,  0.02433365],
#        dtype=float32),
#  array([-0.2887674 ,  0.31337792,  0.16897792,  0.15285847,  0.08330544,
#         -0.6434263 ,  0.19575095,  0.64307743, -0.3073488 , -0.19330774,
#         -0.22198336, -0.5569016 , -0.12530142,  0.11592674,  0.25990528,
#         -0.18662986,  0.14835657, -0.42236343,  0.05206996, -0.79034925,
#          0.24800292,  0.14145698,  0.17548841, -0.2253426 , -0.0457119 ,
#          0.03411219, -0.25010568, -0.2364505 , -0.32595533,  0.05529701,
#          0.42790926,  0.03235989,  0.179981  , -0.24274349, -0.15573423,
#          0.4863907 ,  0.0756855 , -0.17587352, -0.18227401, -0.63069785,
#          0.10694817, -0.3088294 , -0.29685724,  0.01161117,  0.25093758,
#         -0.03534256, -0.16748875, -0.13817778,  0.33213353,  0.1587305 ,
#          0.3010871 , -0.2762545 , -0.09042533,  0.0591519 , -0.16396132,
#          0.04402351,  0.24378297,  0.05589264, -0.5874511 ,  0.1264003 ,
#         -0.08329088,  0.19553494, -0.01793203, -0.1830405 , -0.4091975 ,
#          0.36623052,  0.07752348,  0.3105852 , -0.45533574,  0.48537397,
#         -0.33806154,  0.26555505,  0.55259395, -0.11502026,  0.44239855,
#          0.04715138,  0.10730829, -0.1708843 , -0.2311722 ,  0.14752573,
#         -0.3461083 , -0.13993141, -0.30121738,  0.6173279 , -0.15834676,
#         -0.07849339,  0.08757536,  0.2941294 ,  0.48667812,  0.15679199,
#          0.44970995,  0.27632922,  0.11818227,  0.08466744,  0.60457695,
#          0.26766858,  0.28603306, -0.20340122,  0.21801859,  0.02195218],
#        dtype=float32),
#  array([-0.28731468,  0.28360537,  0.14542982,  0.1516506 ,  0.08646824,
#         -0.61269414,  0.1746491 ,  0.6071218 , -0.29728952, -0.16774784,
#         -0.21449487, -0.51956403, -0.11440814,  0.11251188,  0.24755631,
#         -0.17734246,  0.15124358, -0.40444064,  0.03722896, -0.75896025,
#          0.2328042 ,  0.12896143,  0.18648832, -0.22445312, -0.03753623,
#          0.03494149, -0.23607779, -0.23449394, -0.29240036,  0.06223847,
#          0.41716537,  0.02279082,  0.15714075, -0.21844094, -0.15425166,
#          0.47306472,  0.07534528, -0.16850373, -0.14726594, -0.5934072 ,
#          0.11989687, -0.31040472, -0.27310055,  0.02837733,  0.22275695,
#         -0.01534245, -0.17003778, -0.13263628,  0.30258137,  0.12826346,
#          0.2726075 , -0.2651332 , -0.06440491,  0.07853834, -0.16758105,
#          0.06172323,  0.23733068,  0.03704918, -0.5617545 ,  0.13678573,
#         -0.05441523,  0.17747886, -0.01302555, -0.1466129 , -0.37296972,
#          0.3518105 ,  0.07547646,  0.2947885 , -0.4139509 ,  0.47679886,
#         -0.32511568,  0.24595785,  0.5137889 , -0.11687689,  0.41773623,
#          0.04384032,  0.09143034, -0.14591123, -0.21107282,  0.1164914 ,
#         -0.3050397 , -0.11734109, -0.28544945,  0.5787651 , -0.15093891,
#         -0.04606763,  0.09610379,  0.28182027,  0.45038983,  0.1273024 ,
#          0.4452855 ,  0.2512347 ,  0.09890916,  0.08010929,  0.57197154,
#          0.25799325,  0.26267213, -0.22080818,  0.20384571,  0.02406949],
#        dtype=float32),
#  array([-0.3064124 ,  0.28267553,  0.14497568,  0.15943208,  0.09678659,
#         -0.6413221 ,  0.16421273,  0.6420619 , -0.31942418, -0.17003193,
#         -0.23729774, -0.53291976, -0.12508887,  0.12789302,  0.2543046 ,
#         -0.19550613,  0.1540863 , -0.43954593,  0.02520305, -0.78657025,
#          0.23417039,  0.13063505,  0.1867171 , -0.22549775, -0.0373707 ,
#          0.04389105, -0.26646298, -0.2512614 , -0.29900894,  0.073231  ,
#          0.43032822,  0.0219233 ,  0.15314421, -0.22727275, -0.16403191,
#          0.48548228,  0.0751724 , -0.17438605, -0.14196087, -0.6178001 ,
#          0.12151027, -0.31195194, -0.2835439 ,  0.03528539,  0.21921746,
#         -0.02756172, -0.1740928 , -0.14030106,  0.30973524,  0.1282645 ,
#          0.26382005, -0.2782995 , -0.04180714,  0.08384438, -0.17427586,
#          0.07347488,  0.24810037,  0.03100227, -0.56881464,  0.16365519,
#         -0.03961044,  0.1845913 , -0.01956469, -0.1431692 , -0.3838496 ,
#          0.36261922,  0.07694703,  0.305731  , -0.41898304,  0.49959263,
#         -0.3363733 ,  0.23801288,  0.5187438 , -0.13676794,  0.42423567,
#          0.03657564,  0.0731099 , -0.13746375, -0.21864013,  0.10003076,
#         -0.28712663, -0.11575037, -0.302255  ,  0.5844284 , -0.16221862,
#         -0.03892078,  0.11759484,  0.30180293,  0.4522888 ,  0.11690176,
#          0.4704081 ,  0.2524505 ,  0.0849511 ,  0.07686088,  0.58857214,
#          0.2575219 ,  0.26228434, -0.25531614,  0.22094786,  0.02507069],
#        dtype=float32),
#  array([-0.22432128,  0.22060779,  0.1172134 ,  0.12195063,  0.0691997 ,
#         -0.48377374,  0.13340423,  0.4721034 , -0.23261742, -0.1348283 ,
#         -0.16281743, -0.4119764 , -0.08222136,  0.09013734,  0.19494794,
#         -0.13934219,  0.12062389, -0.31527838,  0.03269161, -0.5924884 ,
#          0.18057404,  0.10864399,  0.14333266, -0.17668211, -0.02993836,
#          0.02782227, -0.18272497, -0.17700408, -0.23321363,  0.0457137 ,
#          0.33141816,  0.01929454,  0.12702414, -0.1622389 , -0.12253215,
#          0.3673969 ,  0.05676361, -0.13408528, -0.12051724, -0.4709662 ,
#          0.09371965, -0.2436924 , -0.2138049 ,  0.02038515,  0.18242459,
#         -0.00926746, -0.13555911, -0.10485464,  0.2332813 ,  0.10071065,
#          0.21449809, -0.21118702, -0.0609825 ,  0.06000941, -0.1402178 ,
#          0.04212879,  0.18357435,  0.02580593, -0.44681543,  0.10398559,
#         -0.04900634,  0.13927977, -0.00711126, -0.11944412, -0.30367887,
#          0.2785395 ,  0.05669435,  0.2296713 , -0.33221927,  0.36924186,
#         -0.25828165,  0.19720355,  0.4041448 , -0.08792613,  0.33269787,
#          0.03490997,  0.07160114, -0.11854714, -0.16377024,  0.09353703,
#         -0.23746234, -0.09713294, -0.2242541 ,  0.4575191 , -0.11141326,
#         -0.03999673,  0.06899656,  0.2146417 ,  0.35755506,  0.10191222,
#          0.34406838,  0.20305434,  0.07905325,  0.0654587 ,  0.44878682,
#          0.20591792,  0.20535281, -0.17193402,  0.16393286,  0.02140129],
#        dtype=float32),
#  array([-0.3203454 ,  0.30058184,  0.16348225,  0.1667909 ,  0.11393489,
#         -0.67828643,  0.18023996,  0.6801292 , -0.3292479 , -0.19724622,
#         -0.24581161, -0.58750147, -0.12886813,  0.12968054,  0.27683872,
#         -0.19501004,  0.17039481, -0.45820618,  0.03409309, -0.8358838 ,
#          0.24650025,  0.13396603,  0.20348604, -0.251244  , -0.04428741,
#          0.0469146 , -0.27684942, -0.2569335 , -0.3153892 ,  0.08035706,
#          0.47479644,  0.02439981,  0.17627971, -0.2345843 , -0.1851656 ,
#          0.5203436 ,  0.0930207 , -0.18239126, -0.14914256, -0.6567642 ,
#          0.13093202, -0.34521824, -0.29326883,  0.0419847 ,  0.24214935,
#         -0.01349541, -0.18901537, -0.15082006,  0.32018253,  0.13881697,
#          0.29063603, -0.29239458, -0.05473347,  0.0985311 , -0.17964077,
#          0.07316934,  0.26980215,  0.04476967, -0.60881233,  0.18168536,
#         -0.05844269,  0.19320413, -0.00579256, -0.13716471, -0.401644  ,
#          0.3929063 ,  0.0955868 ,  0.32543135, -0.43873444,  0.52761775,
#         -0.3519706 ,  0.25099128,  0.5535639 , -0.13045046,  0.45333248,
#          0.03198037,  0.07776135, -0.15240133, -0.23141849,  0.1101264 ,
#         -0.31988677, -0.11931865, -0.30932868,  0.6349541 , -0.15559499,
#         -0.02515423,  0.13169214,  0.3100277 ,  0.47542244,  0.11108901,
#          0.5067321 ,  0.2698052 ,  0.10382962,  0.08833628,  0.62790334,
#          0.27495357,  0.27835166, -0.26922223,  0.22444329,  0.03243645],
#        dtype=float32),
#  array([-0.2916359 ,  0.26478496,  0.14445905,  0.15156831,  0.08841956,
#         -0.6006158 ,  0.15656704,  0.58485407, -0.2870288 , -0.17330717,
#         -0.2096451 , -0.49915943, -0.1101196 ,  0.11237207,  0.23669463,
#         -0.17064525,  0.14988752, -0.40254393,  0.03090357, -0.7296862 ,
#          0.21019363,  0.12107887,  0.17938893, -0.2111458 , -0.02932256,
#          0.04108372, -0.23883891, -0.21936178, -0.2871603 ,  0.06150674,
#          0.39831236,  0.0244155 ,  0.14890276, -0.20916945, -0.14884739,
#          0.45532623,  0.08493476, -0.17551154, -0.14697011, -0.5733051 ,
#          0.10379419, -0.2959673 , -0.2680103 ,  0.03202534,  0.2095679 ,
#         -0.01824871, -0.16815072, -0.1236526 ,  0.28046316,  0.12703036,
#          0.2510797 , -0.25680724, -0.05785915,  0.08275392, -0.16878255,
#          0.06427396,  0.23484646,  0.02980947, -0.5353541 ,  0.14660634,
#         -0.04655474,  0.17277794, -0.00967343, -0.13172431, -0.36155415,
#          0.33784714,  0.07157064,  0.28627905, -0.39454952,  0.4608115 ,
#         -0.31365487,  0.23621602,  0.48493645, -0.12066985,  0.40138245,
#          0.04127167,  0.06589993, -0.135477  , -0.20370503,  0.09475979,
#         -0.27784252, -0.10840931, -0.26648352,  0.550942  , -0.1426559 ,
#         -0.03197167,  0.09854106,  0.27363637,  0.42463395,  0.12039133,
#          0.42878684,  0.23992942,  0.0844906 ,  0.07071927,  0.55276924,
#          0.24634886,  0.2378463 , -0.23445453,  0.20301639,  0.02526069],
#        dtype=float32),
#  array([-0.30465838,  0.27643186,  0.15340537,  0.15412292,  0.10214505,
#         -0.6272745 ,  0.16047111,  0.6224015 , -0.3058273 , -0.17690542,
#         -0.22628471, -0.5282487 , -0.11838642,  0.12337498,  0.25227475,
#         -0.1821406 ,  0.1546646 , -0.4177358 ,  0.02817071, -0.76985663,
#          0.22725472,  0.12135171,  0.19071038, -0.22876123, -0.03054441,
#          0.04340048, -0.25320143, -0.23551579, -0.29564884,  0.07208808,
#          0.4299075 ,  0.02289435,  0.1549025 , -0.22052447, -0.16104975,
#          0.48019442,  0.08119147, -0.17800124, -0.1411769 , -0.59584594,
#          0.1195211 , -0.3123855 , -0.2765706 ,  0.03215051,  0.2216445 ,
#         -0.0175323 , -0.17614785, -0.1387984 ,  0.2961121 ,  0.13026752,
#          0.26513135, -0.27075607, -0.0477938 ,  0.08968426, -0.17034003,
#          0.07382272,  0.24490461,  0.03653126, -0.5554397 ,  0.15744229,
#         -0.04412736,  0.18054451, -0.01083634, -0.13526116, -0.3711814 ,
#          0.35413203,  0.08213235,  0.3026398 , -0.4021462 ,  0.48841378,
#         -0.3274476 ,  0.23662306,  0.5094039 , -0.12216933,  0.41662177,
#          0.03540993,  0.07292309, -0.14055966, -0.20868874,  0.10100839,
#         -0.29242107, -0.11244655, -0.28474867,  0.5788049 , -0.15554333,
#         -0.03254735,  0.11507057,  0.2888057 ,  0.44375342,  0.11129641,
#          0.4635724 ,  0.25002486,  0.08658836,  0.07349709,  0.5774244 ,
#          0.26262766,  0.25657365, -0.24847373,  0.20729588,  0.02735873],
#        dtype=float32),
#  array([-0.30426663,  0.28971103,  0.15282129,  0.15885642,  0.09452662,
#         -0.6306645 ,  0.17570592,  0.63257337, -0.3102476 , -0.17257227,
#         -0.22348267, -0.5364902 , -0.11576733,  0.12322348,  0.2573083 ,
#         -0.18653467,  0.15652667, -0.41644442,  0.03644549, -0.78631425,
#          0.24165788,  0.12417204,  0.19336039, -0.22815779, -0.04235513,
#          0.03962601, -0.24618311, -0.24599005, -0.30348587,  0.07228506,
#          0.43802878,  0.02383928,  0.16700897, -0.22445242, -0.1616198 ,
#          0.48974407,  0.0675197 , -0.16661295, -0.14307123, -0.6053056 ,
#          0.1273744 , -0.32053208, -0.27821955,  0.03061768,  0.23204431,
#         -0.01937802, -0.17375696, -0.13984676,  0.31044963,  0.13478434,
#          0.28277016, -0.26717827, -0.06305063,  0.07580823, -0.16494405,
#          0.06550018,  0.2441934 ,  0.04277128, -0.57608384,  0.14431576,
#         -0.05911325,  0.1811777 , -0.01523232, -0.14681774, -0.3786958 ,
#          0.3554021 ,  0.08743418,  0.30438906, -0.41563052,  0.4904699 ,
#         -0.33056426,  0.23945215,  0.52609175, -0.11711209,  0.4277943 ,
#          0.0401351 ,  0.09174103, -0.1447396 , -0.21328506,  0.12148117,
#         -0.31240055, -0.12094568, -0.29175225,  0.5975743 , -0.1589618 ,
#         -0.04756816,  0.11615929,  0.29540482,  0.45865524,  0.11715704,
#          0.4642989 ,  0.2577312 ,  0.10207887,  0.08706427,  0.58699965,
#          0.2691435 ,  0.27716532, -0.23150514,  0.20572068,  0.02744441],
#        dtype=float32),
#  array([-0.2811658 ,  0.2682405 ,  0.13899466,  0.14837344,  0.0942995 ,
#         -0.60119545,  0.15868886,  0.59299535, -0.29573044, -0.16267692,
#         -0.2202341 , -0.4966476 , -0.11561823,  0.11296574,  0.23654377,
#         -0.1770485 ,  0.14477709, -0.40859896,  0.02812207, -0.7356777 ,
#          0.21413521,  0.12388771,  0.17385344, -0.2168256 , -0.03167549,
#          0.04276776, -0.24982348, -0.23170944, -0.28487965,  0.07061749,
#          0.39743143,  0.02181276,  0.14218304, -0.21591157, -0.15077892,
#          0.45668402,  0.07208024, -0.16572396, -0.13890918, -0.5818103 ,
#          0.11095966, -0.29435295, -0.26700184,  0.03037541,  0.20849566,
#         -0.02726518, -0.1637178 , -0.12900361,  0.29316458,  0.11917856,
#          0.2499518 , -0.2645215 , -0.04198547,  0.07866575, -0.1688172 ,
#          0.06314842,  0.22763917,  0.02617679, -0.5359841 ,  0.15121262,
#         -0.03842521,  0.17138931, -0.01459483, -0.13379556, -0.3647411 ,
#          0.34337008,  0.06937037,  0.28762275, -0.3993546 ,  0.4643782 ,
#         -0.3203904 ,  0.23249057,  0.48916295, -0.12985718,  0.39705676,
#          0.03517229,  0.06519411, -0.13559833, -0.20498748,  0.09492006,
#         -0.2732327 , -0.10906189, -0.28382915,  0.5463481 , -0.14600457,
#         -0.03929879,  0.10279848,  0.28560728,  0.4295315 ,  0.11391677,
#          0.4357677 ,  0.23682572,  0.07660586,  0.06972966,  0.5474654 ,
#          0.24252693,  0.24038327, -0.23676375,  0.20788006,  0.02234807],
#        dtype=float32),
#  ...]

# %%
##independent Features
X_new=np.array(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 2
#       1 ##independent Features
# ----> 2 X_new=np.array(X)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5569,) + inhomogeneous part.

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[0]
# Out:
# array([-0.22453453,  0.21703535,  0.11557314,  0.11826   ,  0.07060363,
#        -0.47909608,  0.13316263,  0.4723991 , -0.23117144, -0.13247146,
#        -0.17043072, -0.40263826, -0.09725586,  0.08863991,  0.18808259,
#        -0.13763784,  0.111093  , -0.32170793,  0.02562423, -0.58466774,
#         0.1693683 ,  0.10259921,  0.14301808, -0.17409126, -0.03000753,
#         0.03028326, -0.19418785, -0.181887  , -0.22661331,  0.05392344,
#         0.31712824,  0.01230068,  0.1140653 , -0.16751239, -0.12182011,
#         0.36573726,  0.05839619, -0.1338338 , -0.11736544, -0.46107197,
#         0.0888481 , -0.23291478, -0.21398734,  0.02428369,  0.16934176,
#        -0.01630282, -0.13186051, -0.10297088,  0.23145503,  0.10026459,
#         0.20981234, -0.21353427, -0.04703735,  0.06551048, -0.13916154,
#         0.04860361,  0.18505472,  0.02569259, -0.43754822,  0.11190655,
#        -0.03759518,  0.13700981, -0.01299792, -0.11227739, -0.2904454 ,
#         0.26578063,  0.05429471,  0.22586615, -0.3227128 ,  0.36335135,
#        -0.257039  ,  0.19217898,  0.39388105, -0.09358615,  0.32149178,
#         0.03192979,  0.06128597, -0.1087384 , -0.16450804,  0.08595674,
#        -0.22694406, -0.09426208, -0.22192203,  0.4452548 , -0.11461235,
#        -0.03340156,  0.07450905,  0.22526118,  0.34383038,  0.09495854,
#         0.3469324 ,  0.19299449,  0.06758343,  0.05944734,  0.44530863,
#         0.19433577,  0.1979726 , -0.18179245,  0.16287598,  0.02211647],
#       dtype=float32)

# %%
X_new[0]
# Out:
# array([], dtype=float64)

# %%
X_new.shape
# Out:
# (1, 0)

# %%
X_new[0].shape
# Out:
# (0,)

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5569,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
import pandas as pd

# %%
## this is the final independent features
df=pd.DataFrame(X[0].reshape(1,-1))
for i in range(1,len(X)):
    df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/b_/hsppj97n5zzbkv6k6m4rpq5c0000gn/T/ipykernel_16626/1817762589.py in ?()
#       3 ## this is the final independent features
# ----> 4 df=pd.DataFrame(X[0].reshape(1,-1))
#       5 for i in range(1,len(X)):
#       6     df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
#       7
#
# ~/Desktop/tryout/venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.216207  0.239545  0.104032  0.112374  0.082477 -0.466196  0.137822
# 1 -0.193356  0.206871  0.086587  0.095822  0.076940 -0.398699  0.105396
# 2 -0.224004  0.258399  0.109422  0.132594  0.072034 -0.512921  0.139317
# 3 -0.292759  0.325016  0.135531  0.154963  0.110923 -0.622693  0.179386
# 4 -0.257790  0.268228  0.123055  0.129405  0.104291 -0.530266  0.150534
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.476254 -0.222950 -0.137382  ...  0.339254  0.194080  0.071031  0.070812
# 1  0.414925 -0.191718 -0.109027  ...  0.299242  0.157049  0.054378  0.052061
# 2  0.468239 -0.235252 -0.170547  ...  0.337649  0.206957  0.062190  0.053607
# 3  0.650676 -0.304797 -0.172119  ...  0.460873  0.255784  0.096641  0.101251
# 4  0.557835 -0.263921 -0.155187  ...  0.399028  0.217131  0.087345  0.086943
#
#          94        95        96        97        98        99
# 0  0.438865  0.190742  0.190763 -0.187745  0.162193  0.028564
# 1  0.367088  0.157486  0.163157 -0.170742  0.144292  0.019021
# 2  0.447795  0.179290  0.148134 -0.218474  0.189056  0.040700
# 3  0.582463  0.258556  0.274167 -0.251514  0.216341  0.030516
# 4  0.497969  0.224949  0.225521 -0.226079  0.180644  0.029771
#
# [5 rows x 100 columns]

# %%
df['Output']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.216207  0.239545  0.104032  0.112374  0.082477 -0.466196  0.137822
# 1 -0.193356  0.206871  0.086587  0.095822  0.076940 -0.398699  0.105396
# 2 -0.224004  0.258399  0.109422  0.132594  0.072034 -0.512921  0.139317
# 3 -0.292759  0.325016  0.135531  0.154963  0.110923 -0.622693  0.179386
# 4 -0.257790  0.268228  0.123055  0.129405  0.104291 -0.530266  0.150534
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.476254 -0.222950 -0.137382  ...  0.194080  0.071031  0.070812  0.438865
# 1  0.414925 -0.191718 -0.109027  ...  0.157049  0.054378  0.052061  0.367088
# 2  0.468239 -0.235252 -0.170547  ...  0.206957  0.062190  0.053607  0.447795
# 3  0.650676 -0.304797 -0.172119  ...  0.255784  0.096641  0.101251  0.582463
# 4  0.557835 -0.263921 -0.155187  ...  0.217131  0.087345  0.086943  0.497969
#
#          95        96        97        98        99  Output
# 0  0.190742  0.190763 -0.187745  0.162193  0.028564       1
# 1  0.157486  0.163157 -0.170742  0.144292  0.019021       1
# 2  0.179290  0.148134 -0.218474  0.189056  0.040700       0
# 3  0.258556  0.274167 -0.251514  0.216341  0.030516       1
# 4  0.224949  0.225521 -0.226079  0.180644  0.029771       1
#
# [5 rows x 101 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
## Independent Feature
X=df

# %%
X.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#              0         1         2         3         4         5         6  \
# 4464 -0.217020  0.255512  0.106173  0.119504  0.074694 -0.487429  0.139651
# 672  -0.244875  0.271410  0.114304  0.134989  0.089957 -0.544205  0.156727
# 359  -0.267663  0.287808  0.125663  0.134431  0.103460 -0.555823  0.162521
# 70   -0.200889  0.218030  0.097211  0.105852  0.079384 -0.435910  0.127253
# 3148 -0.196464  0.213178  0.091318  0.099782  0.073367 -0.412015  0.116882
#
#              7         8         9  ...        91        92        93  \
# 4464  0.487703 -0.226025 -0.155531  ...  0.207455  0.071450  0.063290
# 672   0.523276 -0.257568 -0.178775  ...  0.220620  0.075331  0.068684
# 359   0.577144 -0.270206 -0.162406  ...  0.238139  0.095809  0.087063
# 70    0.451032 -0.213273 -0.126732  ...  0.175443  0.068785  0.063010
# 3148  0.409727 -0.193720 -0.120134  ...  0.172275  0.066354  0.058961
#
#             94        95        96        97        98        99  Output
# 4464  0.447863  0.190330  0.184317 -0.198362  0.172240  0.025990       1
# 672   0.480091  0.212190  0.184667 -0.235810  0.193756  0.035351       0
# 359   0.528695  0.240875  0.241080 -0.220694  0.186851  0.029009       1
# 70    0.401926  0.175555  0.182444 -0.174961  0.151151  0.017436       1
# 3148  0.380369  0.168739  0.166854 -0.162263  0.142802  0.028292       1
#
# [5 rows x 101 columns]

# %%
y_train
# Out:
# 4464    1
# 672     0
# 359     1
# 70      1
# 3148    1
#        ..
# 1758    1
# 290     1
# 1399    1
# 4683    1
# 2172    1
# Name: Output, Length: 4445, dtype: uint8

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9973021582733813

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       147
#            1       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1112
#    macro avg       1.00      0.99      0.99      1112
# weighted avg       1.00      1.00      1.00      1112
